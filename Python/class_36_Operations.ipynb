# %% [markdown]
# # Operations
#
# There are lots of operations with pandas that will be really useful to you, but don't fall into any distinct category. Let's show them here in this lecture:

# %%
import pandas as pd
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_colwidth", 2000)
# pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)

df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Info on Unique Values for a Column:

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df.drop_duplicates(subset="col2",
                     keep="first", inplace=True)
df.head()

# %%
df.sample()
# Out:
#    col1  col2 col3
# 0     1   444  abc

# %%
df1=pd.read_csv("Salaries.csv")
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
df1.shape
# Out:
# (148654, 13)

# %%
df1.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# min       -33.890000    -618.130000       -618.130000    2011.000000    NaN
# 25%     11535.395000   36168.995000      44065.650000    2012.000000    NaN
# 50%     28628.620000   71426.610000      92404.090000    2013.000000    NaN
# 75%     35566.855000  105839.135000     132876.450000    2014.000000    NaN
# max     96570.660000  567595.430000     567595.430000    2014.000000    NaN
#
#        Status
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
pd.set_option('display.min_rows', 500)  # <-add this!
pd.set_option('display.max_rows', 500)
pd.set_option('max_colwidth', 400)
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
df1['JobTitle'].nunique()
# Out:
# 2159

# %%
df1['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#        'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#        'ASSISTANT DEPUTY CHIEF II', 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#        'DEPUTY DIRECTOR OF INVESTMENTS',
#        'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#        'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#        'EXECUTIVE CONTRACT EMPLOYEE', 'DEPARTMENT HEAD V',
#        'COMMANDER III, (POLICE DEPARTMENT)',
#        'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#        'ASSISTANT MEDICAL EXAMINER', 'CAPTAIN, FIRE SUPPRESSION',
#        'CHIEF OF POLICE', 'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#        'INSPECTOR III, (POLICE DEPARTMENT)',
#        'ELECTRONIC MAINTENANCE TECHNICIAN',
#        'ADMINISTRATOR, SFGH MEDICAL CENTER',
#        'LIEUTENANT III (POLICE DEPARTMENT)', 'FIREFIGHTER',
#        'NURSING SUPERVISOR PSYCHIATRIC', 'MAYOR',
#        'LIEUTENANT, FIRE DEPARTMENT', 'INCIDENT SUPPORT SPECIALIST',
#        'ANESTHETIST', 'DISTRICT ATTORNEY',
#        'ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR',
#        'PORT DIRECTOR',
#        'LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBLIC S',
#        'SENIOR PHYSICIAN SPECIALIST', 'FIRE FIGHTER PARAMEDIC',
#        'MANAGER VII', 'TRANSIT SUPERVISOR',
#        'INSPECTOR, BUREAU OF FIRE PREVENTION AND PUBLIC SA',
#        'MANAGER VIII', 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG',
#        'NURSING SUPERVISOR', 'POLICE OFFICER III', "SHERIFF'S LIEUTENANT",
#        'DEPUTY DIRECTOR V', 'SUPERVISING PHYSICIAN SPECIALIST',
#        'DEPARTMENT HEAD IV', 'FORENSIC TOXICOLOGIST',
#        'CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',
#        'SERGEANT III (POLICE DEPARTMENT)', 'DEPUTY SHERIFF',
#        'NURSE MANAGER', 'ELECTRICAL TRANSIT SYSTEM MECHANIC',
#        'CITY ATTORNEY', 'MARINE ENGINEER OF FIRE BOATS',
#        'CHIEF ATTORNEY I (CIVIL & CRIMINAL)',
#        'CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE',
#        'ELECTRICAL TRANSIT SHOP SUPERVISOR I', 'POLICE OFFICER I',
#        'POLICE OFFICER II', 'SERGEANT I (POLICE DEPARTMENT)',
#        'SPECIAL ASSISTANT XXII', 'DEPUTY DIRECTOR IV',
#        'WIRE ROPE CABLE MAINTENANCE SUPERVISOR', 'PUBLIC DEFENDER',
#        'SHERIFF', 'HUMAN RESOURCES DIRECTOR',
#        'INVESTIGATOR, BUREAU OF FIRE INVESTIGATION',
#        'ASSISTANT CHIEF ATTORNEY II', 'DEPUTY DIRECTOR III', 'PHARMACIST',
#        'TRANSIT OPERATIONS SPECIALIST', 'DEPARTMENT HEAD III',
#        'CHIEF PROBATION OFFICER, JUVENILE COURT', "SHERIFF'S SERGEANT",
#        'ASSISTANT INSPECTOR (POLICE DEPARTMENT)',
#        'DIAGNOSTIC IMAGING TECH II', 'DIAGNOSTIC IMAGING TECH III',
#        'CHIEF ADULT PROBATION OFFICER', 'MANAGER VI',
#        'FIRE SAFETY INSPECTOR II', 'MAINTENANCE MACHINIST',
#        'ASSISTANT INSPECTOR III (POLICE DEPARTMENT)',
#        'DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE',
#        'DIRECTOR, EMPLOYEE RELATIONS DIVISION',
#        'ASSISTANT CHIEF ATTORNEY I', 'TRAIN CONTROLLER',
#        'PHYSICIAN ASSISTANT', 'PHYSICIAN SPECIALIST',
#        'AUTOMOTIVE MECHANIC SUPERVISOR I', 'ATTORNEY (CIVIL/CRIMINAL)',
#        'SERGEANT II (POLICE DEPARTMENT)', 'ELECTRICIAN',
#        'NURSE PRACTITIONER',
#        'MECHANICAL SHOP AND EQUIPMENT SUPERINTENDENT',
#        'HEAD ATTORNEY, CIVIL AND CRIMINAL', 'PRINCIPAL CIVIL ENGINEER',
#        'ASSOCIATE ENGINEER', 'PROJECT MANAGER IV', 'PILOT OF FIRE BOATS',
#        'DEPARTMENT HEAD I', 'SENIOR ENGINEER', 'COURT EXECUTIVE OFFICER',
#        'ENGINEER', 'ASSISTANT SHERIFF',
#        'BUILDINGS AND GROUNDS MAINTENANCE SUPERINTENDENT',
#        'ELECTRONIC MAINTENANCE TECHNICIAN ASSISTANT SUPERV',
#        'CLINICAL PHARMACIST', 'DEPARTMENT HEAD II',
#        'CLINICAL NURSE SPECIALIST', 'NURSE MIDWIFE',
#        'ELECTRICAL TRANSIT MECHANIC SUPERVISOR I', 'MANAGER V',
#        'ATTORNEY FOR THE PUBLIC ADMINISTRATOR', 'CHIEF DEPUTY SHERIFF',
#        'SENIOR DEPUTY SHERIFF', 'PROJECT MANAGER III',
#        'TRACK MAINTENANCE WORKER SUPERVISOR I', 'MAYORAL STAFF XVII',
#        'MANAGER VII - MUNICIPAL TRANSPORTATION AGENCY',
#        'HEATING AND VENTILATING INSPECTOR',
#        'ASST. CHIEF PROBATION OFFICER-JUVENILE PROBATION',
#        'DIRECTOR, INFORMATION TECHNOLOGY GROUP',
#        'UTILITY PLUMBER SUPERVISOR II',
#        'COMMUNICATIONS LINE WORKER SUPERVISOR II',
#        'ASSISTANT INSPECTOR II (POLICE DEPARTMENT)', 'ASSESSOR',
#        'MANAGER VIII - MUNICIPAL TRANSPORTATION AGENCY', 'MANAGER IV',
#        'INSPECTOR, (POLICE DEPARTMENT)', 'IS ENGINEER - PRINCIPAL',
#        'REGISTERED NURSE', 'SPECIAL NURSE',
#        'INFORMATION SERVICES MANAGER', 'TRANSMISSION LINE SUPERVISOR I',
#        'SUPERVISING PHARMACIST', 'SEWAGE TREATMENT PLANT SUPERINTENDENT',
#        'TREASURER', 'SENIOR POWER GENERATION TECHNICIAN',
#        'DEPUTY DIRECTOR II', "CHIEF DISTRICT ATTORNEY'S INVESTIGATOR",
#        'LANDSCAPE ARCHITECTURAL ASSOCIATE II',
#        'ARCHITECTURAL ASSOCIATE  I', 'LANDSCAPE ARCHITECT', 'ARCHITECT',
#        'STATIONARY ENGINEER', 'PLUMBING INSPECTOR', 'AUTOMOTIVE MECHANIC',
#        'CHIEF STATIONARY ENGINEER', 'SENIOR COURT STAFF ATTORNEY',
#        'HEAD PARK PATROL OFFICER', 'UNDERSHERIFF',
#        'ASSISTANT ELECTRONIC MAINTENANCE TECHNICIAN', "SHERIFF'S CAPTAIN",
#        'MANAGER III', 'BOARD SECRETARY - MUNICIPAL TRANSPORTATION AGENC',
#        'WATER CONSTRUCTION AND MAINTENANCE SUPERINTENDENT',
#        'LIEUTENANT I, (POLICE DEPARTMENT)',
#        'LIEUTENANT II (POLICE DEPARTMENT)', 'DIAGNOSTIC IMAGING TECH I',
#        'MANAGER II - MUNICIPAL TRANSPORTATION AGENCY',
#        'MANAGER VI - MUNICIPAL TRANSPORTATION AGENCY',
#        'ATTORNEY, TAX COLLECTOR', 'COURT COMMISSIONER',
#        'PRINCIPAL ADMINISTRATIVE ANALYST', 'SENIOR RADIO TECHNICIAN',
#        'ADMINISTRATIVE ENGINEER', 'BUILDING INSPECTOR',
#        'CHIEF WATER SERVICE INSPECTOR', 'POWER GENERATION SUPERVISOR',
#        'TRANSIT OPERATOR', 'UTILITY PLUMBER SUPERVISOR I',
#        'RADIOLOGIC TECHNOLOGIST SUPERVISOR', 'DENTIST',
#        'BUILDING PLANS ENGINEER', 'INSPECTOR II, (POLICE DEPARTMENT)',
#        'TELECOMMUNICATIONS TECHNICIAN SUPERVISOR',
#        'SUPERVISING ELECTRONIC MAINTENANCE TECHNICIAN',
#        'INSTITUTIONAL POLICE SERGEANT', 'TRANSIT POWER LINE SUPERVISOR I',
#        'SENIOR COUNSELOR, JUVENILE HALL', 'COURT ADMINISTRATOR',
#        'PLUMBER SUPERVISOR I', 'COURT COMPUTER SYSTEMS MANAGER',
#        'SENIOR CONSTRUCTION INSPECTOR', 'CRIMINALIST III',
#        'TRANSIT POWER LINE WORKER', 'SEWER REPAIR SUPERVISOR',
#        'SENIOR LIGHT RAIL VEHICLE EQUIPMENT ENGINEER',
#        'TRANSMISSION AND DISTRIBUTION LINE WORKER', 'MANAGER II',
#        'ARCHITECTURAL ASSOCIATE II',
#        'AUTOMOTIVE TRANSIT SHOP SUPERVISOR I',
#        'MANAGER V - MUNICIPAL TRANSPORTATION AGENCY',
#        'IS PROJECT DIRECTOR', 'TRANSIT CAR CLEANER',
#        'CHIEF STATIONARY ENGINEER, WATER TREATMENT PLANT', 'PLUMBER',
#        'DISABILITY ACCESS COORDINATOR',
#        'AUTOMOTIVE MECHANIC ASSISTANT SUPERVISOR',
#        'AUTOMOTIVE MACHINIST ASSISTANT SUPERVISOR', 'LAW LIBRARIAN',
#        'PROJECT MANAGER II', 'SENIOR STATIONARY ENGINEER',
#        'TRANSIT POWER LINE WORKER SUPERVISOR II',
#        'ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN',
#        'IS BUSINESS ANALYST - PRINCIPAL',
#        'POWER GENERATION TECHNICIAN II', 'CABLE SPLICER',
#        'CONSTRUCTION INSPECTOR', 'IS ENGINEER - SENIOR', 'PLANNER V',
#        'CRIME LABORATORY MANAGER', 'SHEET METAL WORKER SUPERVISOR II',
#        'COMMUNICATIONS SYSTEMS TECHNICIAN', 'IS ENGINEER - JOURNEY',
#        'SUPERINTENDENT OF WATER TREATMENT FACILITIES',
#        'STATION AGENT, MUNICIPAL RAILWAY', 'STRUCTURAL ENGINEER',
#        'PUBLIC HEALTH NURSE', 'COURT STAFF ATTORNEY II',
#        'HEAD AIRPORT ELECTRICIAN',
#        'ASSISTANT DIRECTOR OF CLINICAL SERVICES II',
#        'FIRE PROTECTION ENGINEER', 'SPECIAL ASSISTANT XVI',
#        'ASSISTANT DEPUTY DIRECTOR, PORT', 'FIRE RESCUE PARAMEDIC',
#        'DIRECTOR, FISCAL SERVICES', "DISTRICT ATTORNEY'S INVESTIGATOR",
#        'TRANSIT PAINT SHOP SUPERVISOR I', 'ELECTRICIAN SUPERVISOR II',
#        "PRINCIPAL DISTRICT ATTORNEY'S INVESTIGATOR",
#        'BUILDINGS AND GROUNDS MAINTENANCE SUPERVISOR',
#        'SENIOR WATER SERVICE INSPECTOR', 'IS BUSINESS ANALYST - SENIOR',
#        'MAINTENANCE CONTROLLER', 'ELECTRICIAN SUPERVISOR I',
#        'MANAGER, EMPLOYEE RELATIONS DIV', 'TRAFFIC HEARING OFFICER',
#        'ASSISTANT ENGINEER', 'LANDSCAPE ARCHITECTURAL ASSOCIATE I',
#        'CHIEF BUILDING INSPECTOR', 'MAINTENANCE MACHINIST SUPERVISOR I',
#        'MANAGER IV - MUNICIPAL TRANSPORTATION AGENCY', 'UTILITY PLUMBER',
#        'SENIOR ELECTRICAL INSPECTOR', 'ELECTRICAL INSPECTOR',
#        'SENIOR STATIONARY ENGINEER, WATER TREATMENT PLANT',
#        'COMMUNICATION LINE SUPERVISOR I', 'ELECTRICAL LINE WORKER',
#        'MAYORAL STAFF XVI', 'AIRPORT MECHANICAL MAINTENANCE SUPERVISOR',
#        'COURT REPORTER COORDINATOR', 'CHIEF PLUMBING INSPECTOR',
#        'OPERATING ROOM NURSE', 'WELDER',
#        'MENTAL HEALTH TREATMENT SPECIALIST',
#        'TRANSPORTATION SAFETY SPECIALIST',
#        'SENIOR POLICE COMMUNICATIONS DISPATCHER', 'UTILITY SPECIALIST',
#        'CEMENT FINISHER SUPERVISOR II',
#        'ASSISTANT COURT REPORTER COORDINATOR',
#        'PRINCIPAL REAL PROPERTY OFFICER', 'RESEARCH PSYCHOLOGIST',
#        'LOCKSMITH SUPERVISOR I', 'SUPERVISING CHEMIST',
#        'SENIOR PLUMBING INSPECTOR', 'OPERATING ENGINEER, UNIVERSAL',
#        'LABORATORY SERVICES MANAGER', 'MANAGER I',
#        'MANAGER, UNIFIED FAMILY COURT SERVICES',
#        'DIRECTOR, HUMAN RESOURCES', 'SENIOR BUILDING INSPECTOR',
#        'TRANSIT MANAGER II', 'PLANNER IV',
#        'EMERGENCY MEDICAL SERVICES AGENCY SPECIALIST',
#        'PUBLIC SAFETY COMMUNICATIONS DISPATCHER',
#        'WATER OPERATIONS ANALYST', 'CHIEF ELECTRICAL INSPECTOR',
#        'TRAFFIC SIGNAL ELECTRICIAN', 'AUTOMOTIVE BODY AND FENDER WORKER',
#        'APPRENTICE STATIONARY ENGINEER',
#        'AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I',
#        'AUTOMOTIVE MACHINIST', 'SUPERVISING PURCHASER',
#        'CHIEF STATIONARY ENGINEER, SEWAGE PLANT',
#        'COURT COMPUTER FACILITIES COORDINATOR', 'PLUMBER SUPERVISOR II',
#        'MANAGER III - MUNICIPAL TRANSPORTATION AGENCY',
#        'CLAIMS INVESTIGATOR', 'STEAMFITTER',
#        'PROTECTIVE SERVICES SUPERVISOR', 'CARPENTER SUPERVISOR I',
#        'MAYORAL STAFF XV', 'COUNSELOR, LOG CABIN RANCH',
#        'CHIEF HOUSING INSPECTOR', "MEDICAL EXAMINER'S INVESTIGATOR II",
#        'DIRECTOR, JUVENILE HALL', 'IS PROGRAMMER ANALYST - PRINCIPAL',
#        'TRAF SIGNAL ELECTRICIAN SUP II', 'IS ADMINISTRATOR III',
#        "ASSISTANT CHIEF DISTRICT ATTORNEY'S INVESTIGATOR",
#        'STEAMFITTER ASSISTANT SUPERVISOR',
#        'SENIOR STATIONARY ENGINEER, SEWAGE PLANT', 'COURT REPORTER',
#        'AIRPORT ELECTRICIAN', 'AIRPORT ELECTRICIAN SUPERVISOR',
#        'COURT MANAGER', 'HEALTH PROGRAM COORDINATOR III',
#        'SUPERVISING WASTEWATER CONTROL INSPECTOR',
#        'TRAF SIGNAL ELECTRICIAN SUP I', 'LINE INSPECTOR',
#        'PRINCIPAL ADMINISTRATIVE ANAYLST II', 'WATER SERVICE INSPECTOR',
#        'PUBLIC RELATIONS MANAGER',
#        'SENIOR ENVIRONMENTAL HEALTH INSPECTOR',
#        'CONTRACT COMPLIANCE OFFICER II',
#        'SENIOR INDUSTRIAL HYGIENIST DEPT OF PUBLIC HEALTH',
#        'SAFETY OFFICER', 'AUTOMOTIVE MACHINIST SUPERVISOR I',
#        'PLANNER IV-ENVIRONMENTAL REVIEW',
#        'DIVISION DIRECTOR ADULT PROBATION', 'PROTECTIVE SERVICES WORKER',
#        "MEDICAL EXAMINER'S INVESTIGATOR III", 'AUTOMOTIVE SERVICE WORKER',
#        'DIRECTOR, PROBATE', 'IS ADMINISTRATOR - SUPERVISOR',
#        'SENIOR HOUSING INSPECTOR', 'SEWER SERVICE WORKER',
#        'STREET REPAIR SUPERVISOR II', 'ELECTRIC MOTOR REPAIRER',
#        'COMMUNICATIONS DIRECTOR',
#        'COURT COMPUTER APPLICATIONS PROGRAMMER',
#        'DIAGNOSTIC IMAGING TECH IV', 'PROJECT MANAGER I',
#        'ASPHALT FINISHER SUPERVISOR I', 'TRANSIT MANAGER I',
#        'CRIMINALIST II', 'CHIEF MICROBIOLOGIST', 'CHIEF SURVEYOR',
#        'SENIOR ADMINISTRATIVE ANALYST', 'PSYCHIATRIC TECHNICIAN',
#        'SUPERVISING BIOLOGIST', 'AIRPORT OPERATIONS SUPERVISOR',
#        'TRANSIT PLANNER IV', 'MEDIA/SECURITY SYSTEMS SUPERVISOR',
#        "SENIOR DISTRICT ATTORNEY'S INVESTIGATOR",
#        'PRINCIPAL PERSONNEL ANALYST', 'SENIOR PHYSICAL THERAPIST',
#        'SENIOR OCCUPATIONAL THERAPIST', 'SHELTER VETERINARIAN',
#        'CHIEF FIRE ALARM DISPATCHER', 'DEPUTY DIRECTOR I',
#        'EXECUTIVE ASSISTANT TO THE GENERAL MANAGER, RETIRE',
#        'AIRPORT ECONOMIC PLANNER', 'SWITCH REPAIRER',
#        'POWER HOUSE ELECTRICIAN SUPERVISOR I', 'SAFETY ANALYST',
#        'BIOLOGIST III', 'PARKING ENFORCEMENT ADMINISTRATOR',
#        'PRINCIPAL ENVIRONMENTAL HEALTH INSPECTOR',
#        'SENIOR EMPLOYEE RELATIONS REPRESENTATIVE', 'PAINTER SUPERVISOR I',
#        'SENIOR SYSTEMS ACCOUNTANT', 'COUNSELOR, FAMILY COURT SERVICE',
#        'GOVERNMENT AND PUBLIC AFFAIRS MANAGER',
#        'ELECTRONIC INSTRUMENTATION TECHNICIAN,WTR PLTNCN',
#        'CAR AND AUTO PAINTER',
#        'PERFORMANCE ANALYST III - PROJECT MANAGER',
#        'UTILITY PLUMBER APPRENTICE', 'PRINCIPAL MANAGEMENT ANALYST',
#        'LOCKSMITH', 'SENIOR AIRPORT COMMUNICATIONS DISPATCHER',
#        'SENIOR PROPERTY MANAGER, PORT',
#        'HEAVY EQUIPMENT OPERATIONS SUPERVISOR', 'MAINTENANCE PLANNER',
#        'SENIOR STREET INSPECTOR', 'SENIOR REAL PROPERTY OFFICER',
#        'ASSISTANT DIRECTOR OF CLINICAL SERVICES I', 'TRUCK DRIVER',
#        'DIRECTOR, PROBATION SERVICES', 'SENIOR CLAIMS INVESTIGATOR',
#        'TRACK MAINTENANCE WORKER',
#        'WATER AND POWER MAINTENANCE SUPERVISOR I',
#        'ASSOCIATE AFFIRMATIVE ACTION COORDINATOR',
#        'POLICE COMMUNICATIONS SHIFT SUPERVISOR',
#        'STREET ENVIRONMENTAL SERVICES OPERATIONS SUPERVI',
#        'ASSISTANT LAW LIBRARIAN', 'CEMENT FINISHER SUPERVISOR I',
#        'SENIOR PLAN CHECKER',
#        'STATIONARY ENGINEER, WATER TREATMENT PLANT',
#        'MAINTENANCE MANAGER', 'CLERK', 'CRANE MECHANIC SUPERVISOR',
#        'AIRPORT COMMUNICATIONS OPERATOR',
#        'MANAGER I - MUNICIPAL TRANSPORTATION AGENCY',
#        'SUPERVISING CLINICAL PSYCHOLOGIST', 'CHEMIST III',
#        'ARCHITECTURAL ADMINISTRATOR', 'PRINCIPAL REAL PROPERTY APPRAISER',
#        'GENERAL LABORER SUPERVISOR I', 'SUPERVISING PARTS STOREKEEPER',
#        'CITY SHOPS ASSISTANT SUPERINTENDENT', 'INDUSTRIAL HYGIENIST',
#        'HOUSING INSPECTOR', 'MATERIALS COORDINATOR',
#        'PRINCIPAL PERSONAL PROPERTY AUDITOR',
#        'STATIONARY ENGINEER, SEWAGE PLANT', 'LICENSED VOCATIONAL NURSE',
#        'MARITIME MARKETING REPRESENTATIVE',
#        'COURT COMPUTER SYSTEMS ENGINEER II',
#        'COURT COMPUTER APPLICATIONS ANALYST',
#        'SENIOR HUMAN RESOURCES ANALYST',
#        'PRINCIPAL ENVIRONMENTAL SPECIALIST',
#        'SUPERVISING ADULT PROBATION OFFICER',
#        'SUPERVISING PROBATION OFFICER, JUVENILE COURT',
#        'SUPERVISING AUDITOR', 'CLAIMS ADJUSTER',
#        'ELEVATOR AND CRANE TECHNICIAN', 'COURT SUPERVISOR II',
#        'MEMBER, BOARD OF SUPERVISORS', 'PARTS STOREKEEPER',
#        'WATER CONSERVATION ADMINISTRATOR',
#        'TRANSIT CAR CLEANER ASSISTANT SUPERVISOR',
#        'SHEET METAL SUPERVISOR I', 'MAYORAL STAFF XIII',
#        "SENIOR CLAIMS INVESTIGATOR,CITY ATTORNEY'S OFFICE",
#        'SENIOR MAINTENANCE CONTROLLER', 'GLAZIER',
#        'FISCAL SERVICES COORDINATOR', 'SECRETARY TO THE PRESIDING JUDGE',
#        'HEALTH WORKER IV', 'POWER PLANT SUPERVISOR I',
#        'OCCUPATIONAL THERAPIST', 'SURVEY ASSOCIATE',
#        'AUTOMOTIVE SERVICE WORKER ASSISTANT SUPERVISOR',
#        'SENIOR COMMUNITY DEVELOPMENT SPECIALIST I',
#        'CHIEF VICTIM/WITNESS INVESTIGATOR',
#        'MEDIA/SECURITY SYSTEMS SPECIALIST', 'MAYORAL STAFF XIV',
#        'GENERAL LABORER', 'DEPUTY PROBATION OFFICER', 'CARPENTER',
#        'PARK PATROL OFFICER',
#        'EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY',
#        'PHYSICAL THERAPIST', 'SENIOR POWER HOUSE OPERATOR',
#        'PARKING CONTROL OFFICER', 'SENIOR PERSONNEL ANALYST',
#        'INSTITUTIONAL POLICE OFFICER', 'PHARMACY TECHNICIAN',
#        'AUDIOLOGIST', 'ELIGIBILITY WORKER',
#        'ASSISTANT SUPERINTENDENT RECREATION', 'SHEET METAL WORKER',
#        'ASPHALT PLANT SUPERVISOR I', 'SENIOR ACCOUNT CLERK',
#        'COURT INVESTIGATOR', 'STAGE ELECTRICIAN', 'SECURITY ANALYST',
#        'PRINCIPAL PAYROLL AND PERSONNEL CLERK',
#        'SENIOR COMMUNITY DEVELOPMENT SPECIALIST II',
#        'TRAFFIC SIGN MANAGER', 'ELECTRIC MOTOR REPAIR SUPERVISOR I',
#        'TRANSIT PLANNER III', 'REGULATORY SPECIALIST', 'PROBATE EXAMINER',
#        'HOSPITAL ELIGIBILITY WORKER SUPERVISOR',
#        'COURT ASSISTANT - SENIOR, SUPERIOR COURT',
#        'MUNICIPAL STADIUM GROUNDSKEEPER', 'BRICKLAYER',
#        'PLANNER III-ENVIRONMENTAL REVIEW',
#        'ASSISTANT FORENSIC TOXICOLOGIST I',
#        'FARE INSPECTIONS SUPERVISOR/INVESTIGATOR',
#        'EMPLOYMENT AND TRAINING SPECIALIST VI', 'PIPE WELDER',
#        'PARK SECTION SUPERVISOR', 'ENVIRONMENTAL HEALTH INSPECTOR',
#        'PRINCIPAL FARE COLLECTIONS RECEIVER', 'AIRPORT SAFETY OFFICER',
#        'MARRIAGE, FAMILY & CHILD COUNSELOR (MFCC)',
#        'COORDINATOR OF CITIZEN INVOLVEMENT', 'TREE TOPPER SUPERVISOR I',
#        'COURT INTERPRETER SUPERVISOR', 'SURGICAL PROCEDURES TECHNICIAN',
#        'PLANNER III', 'MENTAL HEALTH REHABILITATION WORKER',
#        'PATIENT ACCOUNTS SUPERVISOR', 'STREET INSPECTION SUPERVISOR',
#        'COMMUNICATIONS DISPATCHER II', 'POWER HOUSE OPERATOR',
#        'SENIOR MICROBIOLOGIST', 'IS ENGINEER - ASSISTANT',
#        'ELECTRICAL LINE HELPER', 'ASSISTANT MATERIALS COORDINATOR',
#        "WORKER'S COMPENSATION SUPERVISOR I",
#        'ASSISTANT TO THE DIRECTOR, PUBLIC AFFAIRS       RS',
#        'CLAIMS INVESTIGATOR CITY ATTORNEYS OFFICE', 'IS TRAINER - SENIOR',
#        'SPEECH PATHOLOGIST', 'NURSING ASSISTANT',
#        'COURT TRAINING SPECIALIST', 'ENGINEERING ASSOCIATE II',
#        'CLINICAL PSYCHOLOGIST', 'IS BUSINESS ANALYST', 'GARDENER',
#        'AIRPORT PROPERTY SPECIALIST I', 'BOARD/COMMISSION SECRETARY III',
#        'BENEFITS SUPERVISOR', 'LEGISLATIVE ASSISTANT', 'CEMENT MASON',
#        'LIBRARIAN III', 'REAL PROPERTY OFFICER',
#        'ASSISTANT RENTAL MANAGER, PORT',
#        'ORNAMENTAL IRON WORKER SUPERVISOR I', 'FUSION WELDER',
#        'SUPERVISING WELFARE FRAUD INVESTIGATOR', 'TRAINING COORDINATOR',
#        'PAINTER', 'SENIOR PARKING CONTROL OFFICER', 'SENIOR PURCHASER',
#        'PROGRAM SUPPORT ANALYST', 'FOOD SERVICE MANAGER ADMINISTRATOR',
#        'CONTRACT COMPLIANCE OFFICER I', 'MEDICAL SOCIAL WORK SUPERVISOR',
#        'WATERSHED FORESTER MANAGER',
#        'HEAVY EQUIPMENT OPERATIONS ASSISTANT SUPERVISOR',
#        'ADMINISTRATIVE ANALYST III', 'MOBILE EQUIPMENT SUPERVISOR',
#        'GENERAL UTILITY MECHANIC', 'ASSOCIATE AUDITOR',
#        'COURT SUPERVISOR I',
#        'APPRENTICE STATIONARY ENGINEER, SEWAGE PLANT',
#        'TRACK MAINTENANCE SUPERINTENDENT,MUNICIPAL RAILWAY',
#        'PATTERN MAKER',
#        'EXECUTIVE ASSISTANT TO THE ADMINISTRATOR, S.F.G.H.',
#        'IS PROGRAMMER ANALYST - SENIOR',
#        'ASSISTANT CLERK, BOARD OF SUPERVISORS',
#        'SENIOR REAL PROPERTY APPRAISER', 'EPIDEMIOLOGIST II',
#        'ADMINISTRATIVE SERVICES MANAGER', 'PILEDRIVER SUPERVISOR I',
#        'PERSONNEL PAYROLL REPRESENTATIVE', 'STREET INSPECTOR',
#        'WASTEWATER CONTROL INSPECTOR', 'SENIOR PERSONAL PROPERTY AUDITOR',
#        'BIOLOGIST I/II', 'SENIOR PSYCHIATRIC SOCIAL WORKER',
#        'SENIOR HEALTH PROGRAM PLANNER', 'SENIOR ENVIRONMENT SPECIALIST',
#        "SENIOR INVESTIGATOR, OFFICE OF CITIZEN'S COMPLAINT",
#        'HEALTH CARE ANALYST', 'SENIOR PAYROLL AND PERSONNEL CLERK',
#        'SECRETARY I', 'SOFT FLOOR COVERER SUPERVISOR',
#        'APPRENTICE STATIONARY ENGINEER,WATER TREATMENT PLN',
#        'SECRETARY, COMMISSION ON THE ENVIRONMENT',
#        'PSYCHIATRIC SOCIAL WORKER',
#        'MAINTENANCE MACHINIST ASSISTANT SUPERVISOR',
#        'SENIOR SOCIAL WORKER', 'COORDINATOR, HUMAN RIGHTS COMMISSION',
#        'SENIOR HEALTH EDUCATOR', 'CURATOR IV', 'COUNSELOR II',
#        'MUSEUM SECURITY SUPERVISOR',
#        'SUPERVISOR, TRAFFIC AND STREET SIGNS', 'SENIOR CLERK',
#        'PRINCIPAL ACCOUNTANT', 'FEASIBILITY ANALYST, PORT',
#        'AIRPORT POLICE SERVICES AIDE', "MAYOR'S PROGRAM MANAGER",
#        'PILEDRIVER ENGINE OPERATOR',
#        "SENIOR PUBLIC DEFENDER'S INVESTIGATOR", 'PILE WORKER',
#        'MENTAL HEALTH HEARING OFFICER',
#        'ASSISTANT CHIEF VICTIM/WITNESS INVESTIGATOR', 'CHEMIST I/II',
#        'PARKING METER REPAIRER SUPERVISOR I',
#        'CONSERVATORSHIP/CASE MGNT SUPV', 'DEPUTY COURT CLERK III',
#        'AIRPORT COMMUNICATIONS SUPERVISOR', 'PRINCIPAL CLERK',
#        'PAINTER SUPERVISOR II',
#        'AREA SUPERVISOR, PARKS, SQUARES AND FACILITIES', 'FORESTER',
#        'PUBLIC RELATIONS OFFICER', 'EXECUTIVE SECRETARY III',
#        'CIVIL ENGINEERING ASSOCIATE I',
#        'AIRPORT EMERGENCY PLANNING COORDINATOR',
#        'MOBILE EQUIPMENT ASSISTANT SUPERVISOR',
#        'IS OPERATOR - SUPERVISOR', 'PERSONNEL ANALYST',
#        'CARPENTER SUPERVISOR II', 'EMPLOYMENT AND TRAINING SPECIALIST V',
#        'PARKING HEARING EXAMINER', 'GLAZIER SUPERVISOR I',
#        'SECRETARY, LIBRARY COMMISSION',
#        'EXECUTIVE SECRETARY TO THE CONTROLLER',
#        'ASSISTANT CONSTRUCTION INSPECTOR',
#        'SUPERVISING COURT ADMINISTRATIVE SECRETARY',
#        'SENIOR PARTS STOREKEEPER', 'ELIGIBILITY WORKER SUPERVISOR',
#        'MUSEUM GUARD', 'WELFARE FRAUD INVESTIGATOR',
#        'PRINCIPAL PARTS STOREKEEPER', 'SENIOR MANAGEMENT ASSISTANT',
#        'ASSOCIATE PERFORMANCE AUDITOR',
#        'MAINTENANCE ESTIMATOR AND SCHEDULER', 'PATIENT ACCOUNTS MANAGER',
#        'MARKET RESEARCH SPECIALISTS, PORT', 'SPECIAL ASSISTANT XV',
#        'SENIOR MARRIAGE, FAMILY & CHILD COUNSELOR (MFCC)',
#        'TRAINING OFFICER', 'NUTRITIONIST', 'LIBRARIAN II',
#        'SENIOR GENERAL UTILITY MECHANIC', 'WATER QUALITY TECHNICIAN I/II',
#        'X-RAY LABORATORY AIDE',
#        'EMERGENCY PROTECTIVE ORDERS COMMISSIONER',
#        'SENIOR MEDICAL SOCIAL WORKER', 'HEALTH EDUCATOR',
#        'IS ADMINISTRATOR I', 'CHIEF NURSERY SPECIALIST',
#        'POWERHOUSE ELECTRICIAN SUPERVISOR II',
#        'PROGRAM SPECIALIST SUPERVISOR', 'PORTER', 'IS ADMINISTRATOR II',
#        'SENIOR CENTRAL PROCESSING AND DISTRIBUTION TECHNIC',
#        'PAYROLL SUPERVISOR', 'TRIAL DELAY REDUCTION COORDINATOR',
#        'BUILDING SERVICES TECHNICIAN', 'SENIOR FISCAL TECHNICIAN',
#        'IS TECHNICIAN - SUPERVISOR',
#        'EMPLOYMENT & TRAINING SPECIALIST IV', 'PUBLIC HEALTH TEAM LEADER',
#        'PRINCIPAL INVESTIGATOR, TAX COLLECTOR', 'MICROBIOLOGIST',
#        'CENTRAL PROCESSING AND DISTRIBUTION TECHNICIAN', 'SIGN WORKER',
#        'MEDIA TRAINING SPECIALIST',
#        'MEDICAL RECORDS TECHNICIAN SUPERVISOR',
#        'CUSTODIAL ASSISTANT SUPERVISOR',
#        'SENIOR EMPLOYEE ASSISTANCE COUNSELOR',
#        'MEDIA PRODUCTION SUPERVISOR',
#        'COMMERCIAL DIVISION ASSISTANT SUPERVISOR',
#        'CHILD SUPPORT OFFICER III', 'CRIMINAL JUSTICE SPECIALIST II',
#        'DENTAL HYGIENIST', 'ROOFER SUPERVISOR I', 'JUNIOR ENGINEER',
#        'COURT AD RESOLUTION COORDINATOR',
#        'PATIENT ACCOUNTS ASSISTANT SUPERVISOR', 'TRAINING TECHNICIAN',
#        'TREE TOPPER SUPERVISOR II', 'VICTIM/WITNESS INVESTIGATOR III',
#        'PHYSICAL THERAPIST ASSISTANT', 'ORNAMENTAL IRON WORKER',
#        'HEALTH PROGRAM COORDINATOR II',
#        'INVESTIGATOR, OFFICE OF CITIZEN COMPLAINTS',
#        'ARCHITECTURAL ASSISTANT II', 'HEALTH PROGRAM PLANNER',
#        'CONFIDENTIAL SECRETARY TO DISTRICT ATTORNEY',
#        'ASSOCIATE HUMAN RESOURCES ANALYST',
#        'ASSISTANT DIRECTOR, LOG CABIN RANCH',
#        'MEDICAL RECORDS TECHNICIAN', 'MEDICAL SOCIAL WORKER',
#        'SENIOR ESTATE INVESTIGATOR', 'SECURITY GUARD',
#        "PUBLIC DEFENDER'S INVESTIGATOR",
#        'INVESTIGATOR, TAXI & ACCESS SVCS',
#        'SENIOR FARE COLLECTIONS RECEIVER', 'CHIEF DIETITIAN',
#        'SURVEY ASSISTANT II', 'PUBLIC SERVICE TRAINEE',
#        'LIBRARIAN II - ASIAN ARTS', 'DEPUTY COURT CLERK II',
#        'ASSISTANT STOREKEEPER', 'REAL PROPERTY APPRAISER',
#        'REPRESENTATIVE, HUMAN RIGHTS COMMISSION',
#        'COUNSELOR, JUVENILE HALL', 'TRANSIT PLANNER II',
#        'RETIREMENT ANALYST', 'PLANNER II',
#        'ASSISTANT INDUSTRIAL HYGIENIST', 'EMPLOYEE ASSISTANCE COUNSELOR',
#        'ADMINISTRATIVE ANALYST', 'SPECIALIST IN AGING II',
#        'REHABILITATION SERVICES COORDINATOR',
#        'AFFIRMATIVE ACTION SPECIALIST', 'POWER GENERATION TECHNICIAN I',
#        'TREE TOPPER', 'WATER QUALITY TECHNICIAN III',
#        'EMPLOYEE RELATIONS REPRESENTATIVE', 'STATION OFFICER',
#        'REPRESENTATIVE, COMMISSION ON THE STATUS OF WOMEN',
#        'METAL FABRICATOR', 'EXECUTIVE SECRETARY II',
#        'WATERSHED KEEPER SUPERVISOR', 'MAYORAL STAFF XII',
#        'MEDICAL STAFF SERVICES DEPARTMENT ANALYST', 'UNIT CLERK',
#        'ASSISTANT HEALTH EDUCATOR', 'UTILITY ANALYST',
#        'ENVIRONMENT SPECIALIST', 'LEGAL ASSISTANT',
#        'INVESTIGATOR, TAX COLLECTOR', 'SENIOR ELIGIBILITY WORKER',
#        'SOCIAL WORK SUPERVISOR', 'CONFIDENTIAL SECRETARY CITY ATTORNEY',
#        'IS TRAINER - JOURNEY', 'MEDICAL EVALUATIONS ASSISTANT',
#        'HEALTH CARE BILLING CLERK II', 'PERSONAL PROPERTY AUDITOR',
#        'NURSES STAFFING ASSISTANT', 'PURCHASER', 'PROGRAM SPECIALIST',
#        'COURT ASSISTANT, SUPERIOR COURT',
#        'EMERGENCY PLANNING COORDINATOR', 'PEST CONTROL SPECIALIST',
#        'ROOFER', 'DIRECTOR OF ACTIVITIES, THERAPY AND VOLUNTEER SERV',
#        'COOK', 'SECRETARY, HEALTH COMMISSION', 'LIBRARIAN I',
#        'SURVEY ASSISTNAT I', 'COURT CLERK', 'SEWER MAINTENANCE WORKER',
#        'CHIEF PAYROLL AND PERSONNEL CLERK', 'PORTER SUPERVISOR I',
#        'EMPLOYMENT AND TRAINING SPECIALIST III',
#        'CIVIL ENGINEERING ASSISTANT', "WORKER'S COMPENSATION ADJUSTER",
#        'FARE COLLECTIONS RECEIVER', 'PRINCIPAL PERMIT AND CITATION CLERK',
#        'CUSTOMER SERVICE AGENT SUPERVISOR', 'RECREATION SUPERVISOR',
#        'IS OPERATOR - SENIOR', 'ESTATE INVESTIGATOR',
#        'IS BUSINESS ANALYST - ASSISTANT', 'ADMINISTRATIVE ANALYST II',
#        'TRAFFIC SURVEY TECHNICIAN',
#        'JANITORIAL SERVICES ASSISTANT SUPERVISOR', 'HODCARRIER',
#        'IS TECHNICIAN - SENIOR', 'LEGAL SECRETARY II',
#        'ASSISTANT GENERAL SERVICES MANAGER', 'WHARFINGER II', 'DIETITIAN',
#        'CURATOR III', 'SENIOR TRANSIT TRAFFIC CHECKER',
#        'WATERSHED KEEPER', 'EMPLOYMENT & TRAINING SPECIALIST II',
#        'IS PROGRAMMER ANALYST', 'ELECTRICAL ENGINEERING ASSOCIATE I',
#        'SOCIAL WORK SPECIALIST', 'WATER METER REPAIRER',
#        'ILLUSTRATOR AND ART DESIGNER', 'COURT INTERPRETER',
#        'VOLUNTEER/OUTREACH COORDINATOR', 'PERSONNEL TECHNICIAN',
#        'COMMUNICATIONS DISPATCHER I', 'REHABILITATION COUNSELOR',
#        'PAYROLL CLERK', 'CHIEF CLERK', 'RENT BOARD SUPERVISOR',
#        'ANIMAL CARE SUPERVISOR', 'TILE SETTER',
#        'ARCHITECTURAL ASSISTANT  I', 'CHEF', 'LEGISLATION CLERK',
#        'MAYORAL STAFF IX', 'SECRETARY II', 'TRANSIT FARE INSPECTOR',
#        'ASSOCIATE MUSEUM CONSERVATOR, ASIAN ART MUSEUM',
#        'SENIOR CUSTOMER SERVICE AGENT', 'MANAGEMENT ASSISTANT',
#        'PUBLIC INFORMATION OFFICER', 'SENIOR ACCOUNTANT',
#        'ASSISTANT PURCHASER', 'ASSISTANT RETIREMENT ANALYST',
#        'EPIDEMIOLOGIST I', 'STATISTICIAN', 'PERFORMING ARTS CENTER AIDE',
#        'NURSERY SPECIALIST', 'ASPHALT FINISHER',
#        'LEGAL RESEARCH ASSISTANT', 'SENIOR MUSEUM REGISTRAR',
#        'PRINCIPAL ACCOUNT CLERK', 'FOOD SERVICE SUPERVISOR',
#        'MAIL AND REPRODUCTION SERVICE SUPERVISOR',
#        'CHIEF DEPUTY ADULT PROBATION OFFICER', 'FISCAL TECHNICIAN',
#        'FORENSIC LABORATORY TECHNICIAN', 'FINGERPRINT TECHNICIAN III',
#        'COMMUNITY DEVELOPMENT SPECIALIST', 'MATERIALS TESTING TECHNICIAN',
#        'CUSTODIAL SUPERVISOR', 'PARKING METER REPAIRER',
#        'HOSPITAL ELIGIBILITY WORKER', 'HEALTH PROGRAM COORDINATOR I',
#        'LIBRARY TECHNICAL ASSISTANT II', 'EXECUTIVE SECRETARY I',
#        'MEDICAL RECORDS CLERK', 'STOREKEEPER',
#        'SENIOR FOOD SERVICE SUPERVISOR',
#        "DISTRICT ATTORNEY'S INVESTIGATIVE ASSISTANT",
#        'POLICE SERVICES AIDE', 'WINDOW CLEANER',
#        'CITIZENS COMPLAINT OFFICER',
#        'FIELD SERVICES ASSISTANT SUPERVISOR', 'SOFT FLOOR COVERER',
#        'MATERIALS TESTING AIDE', 'SENIOR PSYCHIATRIC ORDERLY',
#        'CURATOR II', 'VICTIM/WITNESS INVESTIGATOR II',
#        'LEGAL SECRETARY I', 'TRANSIT TRAFFIC CHECKER',
#        'JANITORIAL SERVICES SUPERVISOR', 'CHILD SUPPORT OFFICER II',
#        'PRINCIPAL WATER SERVICES CLERK', 'METALSMITH', 'PLANNER I',
#        'IS OPERATOR - ANALYST', 'HEAD PHOTOGRAPHER',
#        'SENIOR LEGAL PROCESS CLERK', 'WINDOW CLEANER SUPERVISOR',
#        'SENIOR COLLECTIONS OFFICER', 'INVENTORY CLERK', 'ACUPUNCTURIST',
#        'PHYSICAL THERAPY AIDE', 'IS PROGRAMMER ANALYST - ASSISTANT',
#        'FORENSIC AUTOPSY TECHNICIAN', 'DOCUMENT EXAMINER TECHNICIAN',
#        'SENIOR PERMIT AND CITATION CLERK', 'MEDIA PROGRAMMING SPECIALIST',
#        'FOOD SERVICE WORKER', 'MAYORAL STAFF X', 'ZOO CURATOR',
#        'SENIOR SWIMMING INSTRUCTOR', 'SENIOR TRANSIT INFORMATION CLERK',
#        'FINGERPRINT TECHNICIAN II', 'PHARMACY HELPER',
#        'LIBRARY TECHNICAL ASSISTANT I', 'BENEFITS ANALYST',
#        'DISEASE CONTROL INVESTIGATOR',
#        'STORES AND EQUIPMENT ASSISTANT SUPERVISOR',
#        'SENIOR LAUNDRY WORKER', 'ASSISTANT COUNSELOR',
#        'IS TECHNICIAN - JOURNEY', 'CUSTODIAN',
#        'CITY PLANNING GRAPHICS SUPERVISOR',
#        'COURT ADMINISTRATIVE SECRETARY', 'ACCOUNTANT',
#        'SENIOR BOOK REPAIRER', 'WHARFINGER I', 'HEALTH WORKER II',
#        'BAKER', 'SENIOR WATER SERVICES CLERK', 'SENIOR STOREKEEPER',
#        'URBAN FORESTRY INSPECTOR', "MEDICAL EXAMINER'S INVESTIGATOR I",
#        'ENVIRONMENTAL ASSISTANT', 'ASPHALT WORKER', 'SENIOR CLERK TYPIST',
#        'PATIENT ACCOUNTS CLERK',
#        'SECRETARY, BUILDING INSPECTION COMMISSION',
#        'SENIOR MORGUE ATTENDANT', 'IS TRAINER - ASSISTANT',
#        'TRANSIT INFORMATION CLERK', 'ANIMAL CONTROL OFFICER',
#        'PERMIT AND CITATION CLERK', 'ELECTROENCEPHALOGRAPH TECHNICIAN I',
#        'ANIMAL KEEPER', 'ENVIRONMENTAL HEALTH TECHNICIAN I',
#        'SHELTER OFFICE SUPERVISOR', 'DENTAL AIDE', 'MAYORAL STAFF VII',
#        'HEALTH WORKER III', 'VICTIM/WITNESS INVESTIGATOR I', 'CASHIER II',
#        'AIRPORT NOISE ABATEMENT SPECIALIST',
#        'JUNIOR MANAGEMENT ASSISTANT', 'RESEARCH ASSISTANT',
#        'COURT ALTERNATIVE SPECIALIST I', 'SENIOR PERSONNEL CLERK',
#        'INDUSTRIAL INJURY INVESTIGATOR', 'COURT PARALEGAL',
#        'SPECIAL ASSISTANT XVIII', 'CLERK TYPIST',
#        'LEGISLATIVE CALENDAR CLERK',
#        'BUILDING AND GROUNDS PATROL OFFICER', 'SOCIAL WORKER',
#        'ACCOUNT CLERK', 'ARTS PROGRAM ASSISTANT',
#        'HUMAN SERVICES TECHNICIAN', 'ORTHOPEDIC TECHNICIAN II',
#        'ENVIRONMENT HEALTH TECHNICIAN II', 'IS OPERATOR - JOURNEY',
#        'SENIOR OPERATIONS MANAGER', 'SENIOR MEDICAL TRANSCRIBER TYPIST',
#        'VENDOR', 'HEALTH WORKER I', 'MEDICAL TRANSCRIBER TYPIST',
#        'SENIOR UNIT CLERK', 'EMPLOYMENT AND TRAINING SPECIALIST I',
#        'MEDICAL STAFF SERVICES DEPARTMENT SPECIALIST',
#        'JUNIOR ADMINISTRATIVE ANALYST', 'COLLECTIONS OFFICER',
#        'METER READER', 'ELECTIONS WORKER', 'SENIOR PHARMACY HELPER',
#        'ASSISTANT COOK', 'SENIOR TELEPHONE OPERATOR',
#        'INSTITUTIONAL POLICE LIEUTENANT',
#        'DEPUTY SEALER OF WEIGHTS AND MEASURES', 'CASHIER III',
#        'OFFSET MACHINE OPERATOR', 'ACCOUNTANT INTERN',
#        'SHELTER SERVICE REPRESENTATIVE', 'MEDIA PRODUCTION TECHNICIAN',
#        'RECREATION COORDINATOR', 'AGRICULTURAL INSPECTOR',
#        'PATIENT SERVICES FINANCE TECHNICIAN',
#        'RESPIRATORY CARE PRACTITIONER',
#        'INSPECTOR OF WEIGHTS AND MEASURES', 'ANIMAL CARE ATTENDANT',
#        'BEAUTICIAN', "LEGISLATIVE ASSISTANT, CITY ATTORNEY'S OFFICE",
#        'CURATOR I', 'MUSEUM REGISTRAR',
#        'LIGHTING FIXTURE MAINTENANCE WORKER',
#        'BACTERIOLOGICAL LABORATORY ASSISTANT',
#        'ASSISTANT POWER HOUSE OPERATOR',
#        'COMMUNITY DEVELOPMENT ASSISTANT', 'ASSISTANT RECREATION DIRECTOR',
#        'SHELTER OFFICE ASSISTANT SUPERVISOR', 'LIBRARY ASSISTANT',
#        'ANIMAL CARE ASSISTANT SUPERVISOR',
#        'SUPERVISING BUILDING AND GROUNDS PATROL OFFICER',
#        'GRAPHIC ARTIST', 'FINGERPRINT TECHNICIAN I', 'PHOTOGRAPHER',
#        "SHERIFF'S CADET", 'RECREATION SPECIALIST',
#        'HEALTH CARE BILLING CLERK I', 'BENEFITS TECHNICIAN',
#        'MARINA ASSISTANT MANAGER', 'SENIOR MICROPHOTO/IMAGING TECHNICIAN',
#        'SENIOR FOOD SERVICE WORKER', 'SENIOR ASSESSMENT CLERK',
#        'SENIOR MUSEUM PREPARATOR',
#        'SENIOR MATERIALS AND SUPPLIES SUPERVISOR', 'ELECTIONS CLERK',
#        'PLANNER TECHNICIAN', 'PORTER ASSISTANT SUPERVISOR',
#        'SENIOR OFFSET MACHINE OPERATOR', 'CRAFTS INSTRUCTOR',
#        'YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS',
#        'TRANSCRIBER TYPIST', 'PERSONNEL CLERK', 'STABLE ATTENDANT',
#        'CASHIER I', 'LEGAL PROCESS CLERK', 'DIETETIC TECHNICIAN',
#        'BRAILLIST', 'SHADE AND DRAPERY WORKER', 'TELEPHONE OPERATOR',
#        'SIGNAL AND SYSTEMS ENGINEER', 'VICTIM & WITNESS TECHNICIAN',
#        'BOOK REPAIRER', 'SPECIAL ASSISTANT III',
#        'REAL PROPERTY APPRAISER TRAINEE', 'LABORATORY HELPER', 'FARMER',
#        'ASSESSMENT CLERK', 'MUSEUM PREPARATOR',
#        'SWIMMING INSTRUCTOR/POOL LIFEGUARD', 'ASSOCIATE MUSEUM REGISTRAR',
#        'INSTITUTION UTILITY WORKER',
#        'SECRETARY,JUVENILE PROBATION COMMISSION',
#        'HOUSEKEEPER/FOOD SERVICE CLEANER', 'CLAIMS PROCESS CLERK',
#        'PUBLIC SERVICE AIDE-ASSOCIATE TO PROFESSIONALS',
#        'CHIEF TELEPHONE OPERATOR', 'CUSTOMER SERVICE AGENT TRAINEE',
#        'HOME HEALTH AIDE', 'MAYORAL STAFF IV',
#        'MATERIALS AND SUPPLIES SUPERVISOR', 'SUPPLY ROOM ATTENDENT',
#        'SENIOR SUPERVISING PROBATION OFFICER, JUVENILE POU',
#        'STUDENT DESIGN TRAINEE 2/ARC-ENG-PLNG',
#        'PUBLIC RELATIONS ASSISTANT', 'DEPUTY COURT CLERK I',
#        'STUDENT DESIGN TRAINEE 1/ARC-ENG-PLNG', 'LIBRARY PAGE',
#        'JUNIOR CLERK TYPIST', 'JUNIOR CLERK', 'CHILD CARE SPECIALIST',
#        'PUBLIC SERVICE AIDE-SPECIAL PROGRAMS', 'MORGUE ATTENDANT',
#        'MICROPHOTO/IMAGING TECHNICIAN', 'ENVIRONMENTAL SERVICE WORKER',
#        'PRINCIPAL RECREATION SUPERVISOR', 'ANIMAL HEALTH TECHNICIAN',
#        'VETERNIARY LABORATORY TECHNOLOGIST',
#        'STUDENT DESIGN TRAINEE 3/ARC-ENG-PLNG',
#        'PUBLIC SERVICE AIDE-HEALTH SERVICES', 'CRIMINALIST I',
#        'SENIOR TRANSCRIBER TYPIST', 'MAYORAL STAFF II',
#        'IS TECHNICIAN - ASSISTANT', 'PRINCIPAL MUSEUM PREPARATOR',
#        'APPRENTICE GARDENER', 'PUBLIC SERVICE AIDE-ADMINISTRATIVE',
#        'SECRETARY, HUMAN SERVICES COMMISSION',
#        'PUBLIC SERVICE AIDE-ASSISTANT TO PROFESSIONALS',
#        'FIRE ALARM DISPATCHER', 'CHIEF PREPARATOR', 'RECREATION LEADER',
#        'SUPERIOR COURT JUDGE', 'TRAFFIC SIGNAL OPERATOR',
#        'ASSISTANT DIRECTOR, JUVENILE HALL', "SHERIFF'S PROPERTY KEEPER",
#        'TESTING TECHNICIAN', 'WATERSHED WORKER (SEASONAL)', 'PIANIST',
#        'SENIOR DATA ENTRY OPERATOR',
#        'AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS', 'AUDIOMETRIST',
#        'MAYORAL STAFF V', 'RECREATION DIRECTOR', 'BARBER',
#        'SCHOOL CROSSING GUARD', 'MAYORAL STAFF XI', 'COMMISSIONER',
#        'BOARD COMMISSION MEMBER, $200 PER MEETING',
#        'CITY PLANNING INTERN', 'SPECIAL EXAMINER', 'CAMP ASSISTANT',
#        'ORTHOPEDIC TECHNICIAN I', 'WAREHOUSE WORKER',
#        'ASSISTANT RECREATION SUPERVISOR',
#        'BOARD/COMMISSION MEMBER, GROUP V',
#        'AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI',
#        'BOARD/COMMISSION MEMBER, GROUP III',
#        'BOARD/COMMISSION MEMBER, GROUP II', 'SPECIAL ASSISTANT XIV',
#        'PUBLIC SAFETY COMMUNICATIONS TECHNICIAN',
#        'Lieutenant, Fire Suppression', 'Chief of Police',
#        'Electronic Maintenance Tech', 'Chief, Fire Department',
#        'EMT/Paramedic/Firefighter', 'Dept Head V',
#        'Gen Mgr, Public Trnsp Dept', 'Captain 3',
#        'Asst Chf of Dept (Fire Dept)', 'Battlion Chief, Fire Suppressi',
#        'Assistant Deputy Chief 2', 'Transit Manager 2',
#        'Asst Med Examiner', 'Dep Chf of Dept (Fire Dept)',
#        'Executive Contract Employee', 'Captain, Fire Suppression',
#        'Deputy Chief 3', 'Adm, SFGH Medical Center', 'Controller',
#        'Mayor', 'Firefighter', 'Anesthetist',
#        'Senior Physician Specialist', 'Nursing Supervisor Psychiatric',
#        'Dep Dir for Investments, Ret', 'Manager VIII, MTA',
#        'Port Director', 'Lieutenant 3', 'Incident Support Specialist',
#        'District Attorney', 'Manager VIII', 'Dep Dir V',
#        'Emergency Medical Svcs Chief', 'Nursing Supervisor',
#        'Deputy Dir II, MTA', 'Captain, Emergency Med Svcs',
#        'Dept Head IV', 'Cfdntal Chf Atty 2,(Cvl&Crmnl)', 'Commander 3',
#        'City Attorney', 'Inspector 3', 'Nurse Manager',
#        'Human Resources Director', 'Lieut,Fire Prev', 'Police Officer 3',
#        'Supervising Physician Spec', 'Special Assistant 22',
#        'Dept Head III', 'Sergeant 3', 'Forensic Toxicologist',
#        'Chief Atty1 (Civil & Criminal)', 'Transit Supervisor',
#        'Public Defender', 'Wire Rope Cable Maint Sprv',
#        'Nurse Practitioner', 'Dep Dir IV', 'Insp, Fire Dept',
#        'Pharmacist', 'Chf Prob Ofc, Juv Court',
#        'Chief Adult Probation Officer', 'Deputy Dir I, MTA',
#        'Assistant Chief Attorney 2', 'Manager I',
#        'Court Executive Officer', 'Sheriff (SFERS)',
#        'Dir Emp Relations Div', 'Police Officer 2', 'Manager VII',
#        'Registered Nurse', 'Assistant Chief Attorney 1',
#        'Project Manager 4', 'Invstgtor,Fire Dept',
#        'Sergeant, (Police Department)', 'Manager V',
#        'Physician Assistant', 'Sergeant 2',
#        'Electrical Trnst Shop Sprv 1', 'Manager VI', 'Dept Head I',
#        'Fire Safety Inspector 2', 'Diagnostic Imaging Tech II',
#        'Clinical Nurse Specialist', 'Dep Dir III',
#        'Diagnostic Imaging Tech III', 'Undersheriff', 'Dept Head II',
#        'Head Atty, Civil & Criminal', 'Manager VII, MTA',
#        'Mayoral Staff XVII', 'Engineer/Architect Principal',
#        'Assoc Engineer', 'Assistant Sheriff',
#        'Eng/Arch/Landscape Arch Sr', 'Attorney (Civil/Criminal)',
#        'Transmission Line Supervisor 1', 'Physician Specialist',
#        'Automotive Mechanic Sprv 1', 'Engineer', 'Train Controller',
#        'Electrical Transit System Mech', "Sheriff's Lieutenant",
#        'Asst Chf Prob Ofc, Juv Prob', 'IS Manager', 'Clinical Pharmacist',
#        'Chief Deputy Sheriff', 'Electrl Trnst Mech, Asst Sprv',
#        'Assistant Inspector 3', 'Attorney, Tax Collector',
#        'Automotive Mechanic', 'Marine Engineer of Fire Boats',
#        'Board Scty, MTA', 'Heating/Ventilating Inspector', 'Assessor',
#        'Utility Specialist', 'Treasurer', 'IS Business Analyst-Principal',
#        'Project Manager 3', 'Pilot of Fire Boats', 'Court Commissioner',
#        'Director, Info Tech Group', 'Sr Power Generation Tech',
#        'Senior Comm Systems Technican', 'Sewage Treatment Plant Supt',
#        'Special Assistant 21', 'Manager VI, MTA',
#        'Trans and Dist Line Worker', 'Manager IV', 'Law Librarian',
#        "Sheriff's Sergeant", 'Assistant Inspector',
#        'Wire Rope Cable Maint Mechanic', 'Senior Deputy Sheriff',
#        'Water Const&Main Supt', 'Police Officer', 'Dep Dir II',
#        'Supervising Pharmacist', 'IS Engineer-Principal',
#        'Landscape Architect', 'Transit Operations Specialist',
#        'Chief Stationary Engineer', 'Electr Maint Tech Asst Sprv',
#        'Architectural Associate 1', 'Landscape Architect Assoc 2',
#        'Architect', "Sheriff's Captain", 'Utility Plumber Supervisor 2',
#        'Bldgs & Grounds Maint Supt', 'Assistant Inspector 2',
#        'Transit Power Line Worker', 'Fire Rescue Paramedic',
#        'Communications Line Wrk Sprv 2', 'Deputy Sheriff',
#        'Utility Plumber Supervisor 1', 'Manager V, MTA', 'Manager III',
#        'Lieutenant 2', 'Electrician', 'IS Engineer-Journey',
#        'Transit Power Line Sprv1', 'Power Generation Supervisor',
#        'Automotive Trnst Shop Sprv 1', 'Communications Systems Tech',
#        'Trnst Power Line Wrk Sprv 2', 'Airport Mechanical Maint Sprv',
#        'Inspector, (Police Department)', 'Plumbing Inspector', 'Dentist',
#        'Utility Plumber', 'Transit Operator', 'Sr Court Staff Attorney',
#        'Asst Chf, Bur Clm Invest&Admin', 'Court Computer Sys Manager',
#        'Electrical Trnst Mech Sprv 1', 'Public Health Nurse',
#        'Project Manager 2', 'Nurse Midwife', 'Sewer Repair Supervisor',
#        'Inspector 2', 'Special Assistant 19',
#        'Sr Light Rail Veh Equip Eng', 'Manager,Employee Relations Div',
#        'Electrician Supervisor 1', 'Manager II', 'IS Project Director',
#        'Asst.Dep.Dir., Port', 'Head Park Patrol Officer',
#        'Track Maint Wrk Sprv 1', 'Pr Administrative Analyst',
#        'Asst Dir Clinical Svcs 2', 'Trans Safety Specialist',
#        'Institutional Police Sergeant', 'Chief Water Service Inspector',
#        'Architectural Associate 2', 'Mayoral Staff XVI',
#        'Power Generation Technician 2', 'Manager III, MTA',
#        'Crime Lab Mgr', 'Special Assistant 16', 'Stationary Engineer',
#        'Manager IV, MTA', 'Chf District Atty Investigator',
#        'Disability Access Coordinator', 'Sprv Electronic Main Tech',
#        'Director, Fiscal Services', 'Telecommunications Tech Supv',
#        'Senior Stationary Engineer', 'Water Operations Analyst',
#        'Criminalist III', 'Station Agent, Muni Railway',
#        'Administrative Engineer', 'Court Administrator',
#        'Supt Water Treatment Fac', 'Structural Engineer',
#        'Operating Room Nurse', 'Automotive Mechanic Asst Sprv',
#        'Radiologic Tech Sprv', 'Planner 5', 'Mech Shop & Equip Supt',
#        'Court Reporter Coordinator', 'Airport Electrician',
#        'Chf Statnry Eng,WtrTreat Plnt', 'Fire Protection Engineer',
#        'Chief Building Inspector', 'Special Nurse',
#        'Court Staff Attorney II', 'IS Engineer-Senior',
#        'Plumber Supervisor 1', 'Operating Engineer, Universal',
#        'Maintenance Controller', 'Landscape Architect Assoc 1',
#        'Asst Engr', 'Mayoral Staff XV', 'Public Relations Mgr',
#        'Electrical Line Helper', 'Chief Plumbing Inspector',
#        'Chf Stationary Eng, Sew Plant', 'Senior Electrical Inpsector',
#        'Electrical Inspector', 'Ex Asst to Ex Dir, Retirement',
#        'Emergency Med Svcs Agency Spec', 'Construction Inspector',
#        'Automotive Body & Fender Wrk', 'Sr Statnry Eng, Wtr Treat Plnt',
#        'Principal Real Property Ofc', 'Lab Svcs Mgr',
#        'Bldg & Grounds Maint Sprv', 'IS Business Analyst-Senior',
#        'Asst Electronic Main Tech', 'Electrician Supervisor 2',
#        'Assistant Law Librarian', 'Protective Services Supervisor',
#        'Senior Building Inspector', 'Transit Paint Shop Sprv1',
#        'IS Prg Analyst-Principal', 'Dep Dir I',
#        'Traf Signal Electrician Sup II', 'Chief Electrical Inspector',
#        'Court Manager', 'Electrical Line Worker',
#        'Public SafetyComm Supv', 'Auto Body & Fender Wrk Sprv 1',
#        'Utility Plumber Apprentice', 'Supervising Purchaser',
#        'Diagnostic Imaging Tech IV', 'Locksmith Supervisor 1', 'Plumber',
#        'Senior Water Service Inspector', 'Senior Const Inspector',
#        'Diagnostic Imaging Tech I', 'Claims Investigator',
#        'Contract Compliance Officer 2', 'Welder',
#        'Public SafetyComm Disp', 'Director, Juvenile Hall',
#        'Senior Occupational Therapist', 'Maintenance Machinist',
#        'Water Conservation Admin', 'Director, Human Resources',
#        'Traffic Signal Electrician', 'Communication Line Sprv1',
#        'Communications Director', 'Plumber Supervisor 2', 'Planner 4',
#        'Director, Probation Services', "Med Examiner's InvestigatorIII",
#        'Traf Signal Electrician Sup I', 'Div Director, Adult Probation',
#        'Health Program Coordinator 3', 'Sr. Stationary Eng, Sew Plant',
#        'Senior Industrial Hygienist', 'Street Repair Supervisor 2',
#        'Safety Officer', 'Perf Analyst III Project Mgr',
#        'Airport Operations Supervisor', 'Senior Housing Inspector',
#        'Planner 4-Environmental Review', 'Chief Housing Inspector',
#        'Court Reporter', 'Manager II, MTA', 'Senior Plumbing Inspector',
#        'Chief Dep Adlt Prob Of (SFERS)', 'Prnpl Admin Analyst II',
#        'Water Service Inspector', 'Ex Asst to Admin, SFGH',
#        'Building Inspector', 'IS Administrator 3',
#        'Automotive Machinist Sprv 1', 'Asst Dir of Clinical Svcs 1',
#        'Govrnmt/Publ Affairs Mgr', 'Supv Chemist', 'Survey Associate',
#        "Asst Chf Dist Atty's Invstgtor", 'Chief Fire Alarm Dispatcher',
#        'Chief Surveyor', 'Automotive Machinist',
#        'Electr Instrmntn Tech Wtr Poll', 'Transit Planner 4',
#        'Marriage, Family & Child Cnslr', 'Airport Electrician Supervisor',
#        'Fiscal Services Supervisor', 'Supervising Mediator, UFCS',
#        'Chf Victim/Witness Invstgtor', 'Court Supervisor II',
#        'Sr Environmental Hlth Insp', 'Principal Personnel Analyst',
#        'Senior Administrative Analyst', 'Project Manager 1',
#        'Airport Economic Planner', 'Senior Physical Therapist',
#        'Ct Comp App Programmer', 'Mayoral Staff XIII',
#        'Airport Safety Officer', 'Mayoral Staff XIV',
#        "Med Examiner's Investigator II", 'Asst Forensic Toxicologist 1',
#        'Maintenance Manager', 'Cable Splicer',
#        'IS Administrator-Supervisor', 'Supv Biologist',
#        'Pr Environmental Hlth Insp', 'Auto Machinist Asst Sprv',
#        'Shelter Veterinarian', 'Sewer Service Worker',
#        'Real Estate Devt. Mgr, SFMTA', 'Statnry Eng Water Treat Plant',
#        'Carpenter Supervisor 2', 'Senior Emp Relations Repres',
#        'Maintenance Machinist Sprv 1', 'Criminalist II',
#        'Investigator/Transit Fare Supv', 'Biologist III',
#        "District Attry's Investigator", 'Sr District Atty Investigator',
#        'Automotive Service Worker', 'Stationary Eng, Sewage Plant',
#        'Sheet Metal Supervisor 1', 'Media/Security Syst Supv',
#        'Protective Services Worker', 'Steamfitter Supervisor I',
#        'Accountant IV', 'Senior Property Manager, Port',
#        'Employment & Training Spec 6', 'Line Inspector',
#        'Pub Safety Communication Coord', 'Senior Personnel Analyst',
#        'Member, Board of Supervisors', 'Hospital Elig Wrk Supervisor',
#        'Sprv Clincal Psychologist', 'Transit Manager 1',
#        'Heavy Equipment Ops Sprv', 'Special Assistant 15', 'Steamfitter',
#        'Carpenter Supervisor 1', 'Principal Mgmt Analyst',
#        'Senior Real Property Officer', 'Senior Plan Checker',
#        'Auditor III', 'Director, Probate', 'Ex Dir, SE Com Fac Comm',
#        'Senior Claims Investigator', 'Track Maintenance Worker',
#        'Pharmacy Technician', 'Architectural Administrator',
#        'IS Administrator 1', 'Safety Analyst', 'Switch Repairer',
#        'Institutional Police Officer', 'Chemist III',
#        'Senior Power House Operator', 'Industrial Hygienist',
#        'Crane Mechanic Supervisor', 'Claims Adjuster',
#        'Senior Street Inspector', 'Pr Real Property Appraiser',
#        'Street Environ Svcs Oprs Supv', 'EEO Senior Specialist',
#        'Pr Personal Property Auditor', 'Medical Records Tech Sprv',
#        'Maintenance Planner', 'Court Interpreter Supervisor',
#        'Materials Coordinator', 'Parking Enforcement Admin',
#        'Maritime Marketing Repr', 'SrClaimsInvstgtor,Cty Atty Ofc',
#        'Sr Community Dev Spec 2', 'Principal Environ Specialist',
#        'Pr Payroll & Personnel Clerk', 'Sr Counselor, Juvenile Hall',
#        'Counselor, Family Court Svc', 'Asst Superintendent Rec',
#        'Sprv Wastewater Cont Inspector', 'Research Psychologist',
#        'Housing Inspector', 'Watershed Forester',
#        'Ct Comp Sys Engineer II', 'Sprv Prob Ofc, Juv Court',
#        'Ct Comp App Analyst', 'Truck Driver',
#        'Coord of Citizen Involvement', 'Sr Human Resources Analyst',
#        'Occupational Therapist', 'Car and Auto Painter', 'Accountant III',
#        'Water & Power Maint Sprv 1', 'Sheet Metal Worker',
#        'Elevator and Crane Technician', 'Physical Therapist',
#        'Audiologist', 'Licensed Vocational Nurse',
#        "Worker's Comp Supervisor 1", 'General Laborer Supervisor 1',
#        'Electric Motor Repair Sprv 1', 'Security Analyst',
#        'Coord, Human Rights Comm', 'Piledriver Supervisor 1',
# ...
#        'Sr Cent Proc & Dist Tech', 'Employment & Training Spec 3',
#        'Senior Medical Social Worker', 'Librarian 2 - Asian Arts',
#        'Deputy Court Clerk III', 'Training Officer',
#        'Public Relations Officer', 'Junior Engineer',
#        'Medical Records Technician', 'Traffic Sign Manager',
#        'Main Machinist Asst Sprv', 'Sr Employee Asst Counselor',
#        'Ex Asst to the Controller', 'Parking Hearing Examiner',
#        'IS Technician-Supervisor', 'Secretary, Library Commission',
#        'Rent Board Supervisor', 'Medical Evaluations Assistant',
#        'Employee Relations Representat', 'Criminal Justice Specialist 2',
#        'Emp & Training Spec 4', 'IS Trainer-Senior', 'Museum Guard',
#        'Assistant Const Inspector', 'Librarian 2',
#        'Medical Social Worker', 'Principal Clerk', 'Dental Hygienist',
#        'Personnel Analyst', 'Market Research Spec, Port',
#        'Mayoral Staff XII', 'Water Quality Tech III',
#        'Child Support Officer III', 'Asst Dir, Log Cabin Rnch',
#        'Health Educator', 'Victim/Witness Investigator 3',
#        'Cfdntal Sctry to Distric Atty', 'Rep, Human Rights Comm',
#        'Power Generation Technician 1', 'Nutritionist',
#        'Invstgtor Ofc Citizen Cmplnts', 'Senior Management Assistant',
#        'Arborist Technician Supv II', 'Sr General Utility Mechanic',
#        'Executive Secretary 3', 'Asst General Services Manager',
#        'Senior Benefits Analyst', 'Fingerprint Technician 3',
#        'Senior Fiscal Technician', 'Media Training Specialist',
#        'Building Services Technician', 'Roofer Supervisor 1',
#        'Central Processing & Dist Tech', 'Microbiologist',
#        'Counselor, Juvenile Hall', 'AprntcStatnry Eng,WtrTreatPlnt',
#        'Senior Clerk Typist', 'Media Production Supv',
#        'Chief Nursery Specialist', 'Executive Secretary 2',
#        "Public Defender's Investigator", 'Rehabilitation Svcs Coord',
#        'Painter', 'Dir of Act, Therapy & Vol Svcs',
#        'Investigator,Taxi & AccessSvcs', 'Purchaser',
#        'Specialist in Aging 2', 'Chief Dietitian',
#        'Personnel/Payroll Repres', 'Pattern Maker',
#        'IT Operations Support Admin IV', 'IS Operator-Senior',
#        'Public Health Team Leader', 'Vet Laboratory Technologist',
#        'Health Program Coordinator 2', 'Communications Dispatcher 2',
#        'Survey Assistant II', 'X-Ray Laboratory Aide',
#        'Cfdntal Sctry to City Atty', 'Employee Assistance Counselor',
#        'Watershed Keeper Supervisor', 'Rep, Comm Status of Women',
#        'Training Technician', 'Health Program Planner',
#        'Social Work Supervisor', 'Ornamental Iron Worker',
#        'Estate Investigator', 'Senior Estate Investigator',
#        'Parking Meter Repairer Sprv 1', 'Eligibility Worker Supervisor',
#        'Mayoral Staff X', 'Investigator, Tax Collector', 'Cook',
#        'Program Specialist', 'Recreation Supervisor',
#        'Patient Accounts Supervisor', 'Physical Therapist Assistant',
#        'Sr Fare Collections Receiver', 'Emergency Planning Coordinator',
#        'Assistant Industrial Hygienist', 'Planner 2', 'Transit Planner 2',
#        "Worker's Compensation Adjuster", 'EEO Programs Specialist',
#        'Engineering Associate 1', 'Environmental Spec',
#        'Parts Storekeeper', 'Librarian 1', 'Hospital Eligiblity Worker',
#        'Court Clerk', 'Health Care Analyst', 'IS Trainer-Journey',
#        'IS Operator-Journey', 'Sctry, Bldg Inspection Comm',
#        'IS Business Analyst-Assistant', 'Legal Assistant',
#        'Utility Analyst', 'Architectural Assistant 2',
#        'Med Staff Svcs Dept Anl', 'Personal Property Auditor',
#        'Apprentice Stationary Engineer', 'Mayoral Staff XI',
#        'Payroll Clerk', 'Customer Service Agent Supv',
#        'Assoc Musm Cnsrvt, AAM', 'Arborist Technician',
#        'Prpl Permit and Citation Clerk', 'Mayoral Staff IX',
#        'Secretary, Health Commission', 'Psychiatric Technician',
#        'Eligibility Worker', 'Integrated Pest Mgmt Specialst',
#        'Senior Personnel Clerk', 'Roofer', 'Dietitian',
#        'Senior Social Worker', 'Court Asst., Superior Court',
#        'Chief Clerk', 'Secretary 1', 'Fare Collections Receiver',
#        'Soft Floor Coverer', 'Senior Clerk', 'Senior Eligibility Worker',
#        'Porter Supervisor 1', 'Gardener', "Med Examiner's Investigator I",
#        'Sewer Maintenance Worker', 'Assistant Retirement Analyst',
#        'Legal Secretary 2', 'Janitorial Svcs Asst Sprv',
#        'Community Development Spec', 'Wharfinger 2', 'Curator 3',
#        'Customer Service Agent', 'Pharmacy Helper', 'Hodcarrier',
#        'Emp & Training Spec 2', 'Custodial Assistant Supervisor',
#        'Patient Accounts Asst Sprv', 'Watershed Keeper',
#        'Illustrator and Art Designer', 'Environmental Hlth Tech 2',
#        'Senior Museum Registrar', 'Animal Care Supervisor',
#        'IS Programmer Analyst', 'Survey Assistant I',
#        'Materials Testing Aide', 'Principal Account Clerk',
#        'Court Administrative Secretary', 'Events & Facilities Specialist',
#        'Mail & Reproduction Svc Sprv', 'Transit Fare Inspector',
#        'Management Assistant', 'IS Technician-Senior',
#        'Court Supervisor I', 'Senior Parts Storekeeper',
#        'Traffic Survey Technician', 'Assistant Health Educator',
#        'Forensic Laboratory Technician', 'Research Asst, Superior Court',
#        'Accountant II', 'Chief Preparator',
#        'Document Examiner Technician', 'Volunteer/Outreach Coord',
#        'Health Worker 4', 'Dist Atty Investigator (SFERS)',
#        'Deputy Court Clerk II', 'Assistant Storekeeper',
#        'Library Technical Assistant 2', 'Principal Parts Storekeeper',
#        'Citizens Complaint Officer', 'Security Guard',
#        'Court Interpreter', 'Principal Water Services Clerk', 'Chef',
#        'Victim/Witness Investigator 2', 'Custodial Supervisor',
#        'Fiscal Technician', 'Public Information Officer',
#        'Window Cleaner', 'Epidemiologist 1',
#        'Materials Testing Technician', 'Senior Transit Traffic Checker',
#        'Window Cleaner Supervisor', 'Rehabilitation Counselor',
#        'Cement Mason', 'Legal Secretary 1',
#        'Deputy Probation Officer SFERS', 'Nursery Specialist',
#        'Water Meter Repairer', 'Health Program Coordinator 1',
#        'Collection Supervisor', 'Fingerprint Technician 2',
#        'Nurses Staffing Assistant', 'Child Support Officer II',
#        'Architectural Assistant 1', 'Graphics Supervisor',
#        'Legislation Clerk', 'Executive Secretary 1', 'Tile Setter',
#        'DA Investigative Assist', 'Aquatics Facility Supervisor',
#        'Curator 2', 'Library Technical Assistant 1', 'Acupuncturist',
#        'Benefits Analyst', 'Assistant Purchaser',
#        'Snr Permit and Citation Clerk', 'Forensic Autopsy Technician',
#        'Patient Accounts Clerk', 'Janitorial Services Supervisor',
#        'Porter', 'IS Program Analyst-Assistant', 'Therapy Aide',
#        'Depty Sealer of Weights & Meas', 'IS Operator-Analyst',
#        'Stores & Equip Asst Sprv', 'Field Svcs Asst Supv',
#        'Parking Meter Repairer', 'Food Service Supervisor',
#        'Senior Collections Officer', 'Storekeeper',
#        'Airport Noise Abatement Spec', 'Asphalt Worker',
#        'Permit and Citation Clerk', 'Secretary 2', 'Senior Book Repairer',
#        'Senior Legal Process Clerk', 'Medical Records Clerk',
#        'Engineering Assistant', 'Health Care Billing Clerk 2',
#        'Health Worker 3', 'Senior Pharmacy Helper',
#        'Senior Psychiatric Orderly', 'Senior Morgue Attendant',
#        'Media Programming Spec', 'Asphalt Finisher',
#        'Disease Control Investigator', 'Health Worker 2', 'Planner 1',
#        'IS Technical-Journey', 'Employment & Training Spec 1',
#        'Senior Water Services Clerk', 'Accountant I',
#        'Transit Traffic Checker', 'Senior Account Clerk',
#        'Electroencephalograph Tech 1', 'Personnel Technician',
#        'Environmental Hlth Tech 1', 'Respiratory Care Practitioner',
#        'Research Assistant', 'Junior Administrative Analyst',
#        'Metalsmith', 'Dental Aide', 'Industrial Injury Investigator',
#        'Baker', 'Victim/Witness Investigator 1',
#        'Urban Forestry Inspector', 'Unit Clerk', 'Criminalist I',
#        'Environmental Assistant', 'ASR Senior Office Specialist',
#        'Supv Bldg Grounds Patrol Ofcr', 'Senior Storekeeper',
#        'Junior Management Assistant', 'Custodian',
#        'Shelter Officer Supervisor', 'Senior Food Service Supervisor',
#        'IS Trainer-Assistant', 'Sign Worker', 'Health Worker 1',
#        'Patient Svcs Finance Tech', 'Animal Control Officer',
#        'Bldg & Grounds Patrol Officer', 'Senior Laundry Worker',
#        'Court Alternative Specialist 1', 'Communications Dispatcher 1',
#        'Social Worker', 'Orthopedic Technician 2', 'Animal Keeper',
#        'Transit Information Clerk', 'Community Development Asst',
#        'Arts Program Assistant', 'Senior Unit Clerk',
#        'Human Services Technician', 'Med Staff Svcs Dept Spc',
#        'Museum Registrar', 'Medical Transcriber Typist',
#        'Elections Worker', 'Senior Telephone Operator',
#        'Assistant Counselor', 'Collections Officer', 'Clerk Typist',
#        'Sprv Adult Prob Ofc (SFERS)', 'Admin Analyst 3',
#        'Recreation Coordinator', 'Chief Telephone Operator',
#        'Sr Medical Transcriber Typist', 'Public Service Trainee',
#        'Swimming Instr/Pool Lifeguard', 'Administrative Analyst II',
#        'Inspector, Weights & Measures', 'Food Service Worker',
#        'Mayoral Staff V', 'Principal Museum Preparator',
#        'Library Assistant', 'Laboratory Technician II', 'Farmer',
#        'Account Clerk', 'Offset Machine Operator',
#        'Mobile Equipment Supervisor', 'Meter Reader', 'Photographer',
#        'Inventory Clerk', 'Media Production Tech',
#        'Assessor-Recorder Office Spec', 'Porter Assistant Supervisor',
#        'Marina Assistant Manager', 'Benefits Technician',
#        'Health Care Billing Clerk 1', 'Mayoral Staff VII',
#        'Fingerprint Technician 1', 'Transcriber Typist',
#        'Recreation Specialist', 'Sr. Microphoto/Imaging Tech.',
#        'Shelter Service Rep', 'Elections Clerk', 'Curator 1',
#        'Planner Technician', 'Senior Museum Preparator', 'Graphic Artist',
#        'Agricultural Inspector', 'Cashier 1', 'Shelter Office Asst Supv',
#        'Claims Process Clerk', 'Assistant Cook',
#        'Senior Offset Machine Operator', 'Animal Care Asst Supv',
#        'Animal Care Attendant', 'Youth Comm Advisor', 'Cashier 2',
#        'Shade and Drapery Worker', 'Sr Materials & Supplies Sprv',
#        'Crafts Instructor', 'Dietetic Technician', 'Legal Process Clerk',
#        'Admission Attendant', 'Accountant Intern',
#        'Associate Museum Registrar', 'Stable Attendant',
#        'Personnel Clerk', 'PrDAInvest,SpecUnit (SFERS)',
#        'Lighting Fixture Maint Worker', 'Braillist',
#        'Chief Deputy Adlt Probation Of', 'Head Airport Electrician',
#        'Telephone Operator', 'Head Photographer',
#        'Laboratory Technician I', 'ASR-Office Assistant',
#        'Assessment Clerk', 'Senior Food Service Worker',
#        'Museum Preparator', 'Senior Maintenance Controller',
#        'Book Repairer', 'Sheet Metal Wrk Supervisor 2',
#        'Senior Transcriber Typist', 'Aquatics Facility Asst Supv',
#        'Housekeeper/Food Service Clnr', "Sheriff's Cadet",
#        'Special Assistant 3', 'Institution Utility Worker',
#        'Materials/Supplies Supervisor', 'Home Health Aide',
#        'Public Relations Assistant', 'Apprentice Gardener',
#        'Supply Room Attendant', 'Sctry, Juv Probation Comm',
#        'Library Page', 'Assistant Power House Operator',
#        'Junior Clerk Typist', 'Special Assistant 14',
#        'Microphoto/Imaging Technician', 'Junior Clerk',
#        'Child Care Specialist', 'Beautician',
#        'StdntDsgnTrain3, Arch/Eng/Plng', 'StdntDsgnTrain1, Arch/Eng/Plng',
#        'Sr Opers Mgr', 'Sr Transit Information Clerk', 'Morgue Attendant',
#        'PS Aide to Prof', 'Traffic Signal Operator',
#        'Ct Comp Facilities Coord', 'Mayoral Staff II',
#        'Victim & Witness Technician', 'Fire Alarm Dispatcher',
#        'Police Services Aide', 'Assistant Director, Probate',
#        'Public Service Aide-Admin', 'Building Plans Engineer',
#        'Painter Supervisor 2', 'Publ Svc Aide-Asst to Prof',
#        'Legislative Calendar Clerk', 'Public Svc Aide-Public Works',
#        'PS Aide Health Services', 'Court Paralegal',
#        'Animal Health Technician', 'Environmental Service Worker',
#        'StdntDsgn Train2/Arch/Eng/Plng', 'Principal Recreation Sprv',
#        'Statistician', 'Senior Assessment Clerk',
#        'Signal and Systems Engineer', 'Mayoral Staff IV',
#        'Dir, Log Cabin Ranch (SFERS)', 'Superior Court Judge',
#        'Audiometrist', 'Legislative Asst City Atty Ofc',
#        'Swimming Instructor', 'Asst Director, Juvenile Hall',
#        'Sctry, Human Svcs. Commission', 'Deputy Sheriff 1',
#        'Customer Service Agent Trainee', 'Wharfinger 1',
#        "Sheriff's Property Keeper", 'Recreation Leader',
#        'Pr DistAtty Invstgtor,SpecUnit', 'Counselor, Juvenile Hall SFERS',
#        'Counselor,Log Cabin Rnch SFERS', 'Pool Lifeguard',
#        'Special Assistant 10', 'Sheriff', 'Special Assistant 13',
#        'Watershed Worker (Seasonal)', 'City Planning Intern',
#        'Senior Data Entry Operator', 'School Crossing Guard',
#        'Orthopedic Technician 1', 'Special Assistant 18', 'Pianist',
#        'Commissioner No Benefits', 'Recreation Director',
#        'Testing Technician', 'Special Examiner',
#        'Brd Comm Mbr, M=$200/Mtg', 'Child Support Officer I',
#        'Camp Assistant', 'Animal Control Supervisor',
#        'Musm Exhibit Packer & Repairer', 'Administrative Analyst I',
#        'Special Assistant 8', 'Assistant Recreation Director',
#        'BdComm Mbr, Grp5,M$100/Mo', 'Barber',
#        'Public Service Aide-Technical', 'BdComm Mbr, Grp3,M=$50/Mtg',
#        'BdComm Mbr, Grp2,M=$25/Mtg', 'Battalion Chief, Fire Suppress',
#        'Administrator, DPH', 'Capt,Fire Prev or Fire Invsgtn',
#        'Electrical Transit Shop Sprv 1', 'Managing Attorney',
#        'Civil Case Settlmnt Specialist', 'IT Operations Support Admin II',
#        'IT Operations Support Admin V', 'Transit Power Cable Splicer',
#        'City Shops Asst Superintendent', 'Industrial Engineer',
#        'Emergency Services Coord III', 'Duty Officer',
#        'Admin Hearing Examiner', 'Transit Fare Insp. Sup/Invst.',
#        'IT Operations Support Admn III', 'Cement Finisher Supervisor 2',
#        'Payroll Supervisor', 'IT Operations Support Admin I',
#        'Airport Communications Officer', 'Media Production Specialist',
#        'Emergency Services Coord I', 'Water Meter Shop Supervisor 1',
#        'Emergency Services Coord II', 'Auditor I', 'Deputy Court Clerk I',
#        'Performance Analyst I', 'Mgr Museum Security Services',
#        'Captain, (Fire Department)', 'Emergency Services Assistant',
#        'Commissioner 16.700c, No Pay', 'Public Safety Comm Tech',
#        'Drug Court Coordinator', 'IS Technician Assistant',
#        'Chief Investment Officer', 'Manager, Dept Public Health',
#        'Chief Forensic Toxicologist', 'Lieutenant (Police Department)',
#        'Deputy Sheriff (SFERS)', 'Undersheriff (SFERS)',
#        'Light Rail Vehicle Equip Eng', 'Electrician Supervisor II',
#        'Transportation Planner IV', 'HSA Sr Eligibility Worker',
#        'Transportation Planner III', 'Sr Sprv Prob Ofc, Juv Prob',
#        'Biologist', 'Administrative Hearing Sup', 'Chemist',
#        'HH Mechanical Shop Sprv', 'Auto Body&Fender Wrk Asst Sprv',
#        'Instructional Designer', 'Transportation Planner II',
#        'Water Quality Technician', 'HSA Emp & Training Spec II',
#        'HSA Social Worker', 'Legislative Clerk',
#        'Sen Hospital Eligibility Wrkr', 'Marina Assistant',
#        'Special Assistant 11', 'Hospital Eligibility Worker',
#        'Personnel Trainee', 'ACPO,JuvP, Juv Prob (SFERS)',
#        'Apprentice Cement Mason I', 'Marina Associate Manager',
#        'Sr Cnselor, Juv Hall (SFERS)', 'Forensic Toxicologist Supervis',
#        'Conversion', 'Cashier 3', 'Not provided'], dtype=object)

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
df1.loc[df1["EmployeeName"]=="GARY JIMENEZ","JobTitle"]="$_@@#_--"
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                        $_@@#_--
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
df1['JobTitle'].value_counts()
# Out:
# Transit Operator                                      7036
# Special Nurse                                         4389
# Registered Nurse                                      3736
# Public Svc Aide-Public Works                          2518
# Police Officer 3                                      2421
# Custodian                                             2418
# TRANSIT OPERATOR                                      2388
# Firefighter                                           2359
# Recreation Leader                                     1971
# Patient Care Assistant                                1945
# Deputy Sheriff                                        1933
# Police Officer                                        1476
# SPECIAL NURSE                                         1402
# Public Service Trainee                                1328
# REGISTERED NURSE                                      1219
# Police Officer 2                                      1141
# Attorney (Civil/Criminal)                             1126
# Porter                                                1095
# Sergeant 3                                            1047
# General Laborer                                       1033
# EMT/Paramedic/Firefighter                              918
# Gardener                                               894
# Parking Control Officer                                868
# Senior Clerk                                           840
# Library Page                                           799
# CUSTODIAN                                              796
# FIREFIGHTER                                            794
# POLICE OFFICER III                                     779
# Clerk                                                  764
# Eligibility Worker                                     760
# Senior Clerk Typist                                    745
# Licensed Vocational Nurse                              707
# RECREATION LEADER                                      692
# DEPUTY SHERIFF                                         685
# Nurse Practitioner                                     674
# Stationary Engineer                                    660
# Electrical Transit System Mech                         631
# PS Aide to Prof                                        627
# Protective Services Worker                             616
# Senior Administrative Analyst                          615
# Medical Evaluations Assistant                          613
# Transit Supervisor                                     613
# Museum Guard                                           606
# Junior Clerk                                           596
# Publ Svc Aide-Asst to Prof                             574
# Lieutenant, Fire Suppression                           572
# Senior Eligibility Worker                              571
# MENTAL HEALTH REHABILITATION WORKER                    559
# Community Police Services Aide                         559
# School Crossing Guard                                  558
# Food Service Worker                                    544
# PUBLIC SERVICE AIDE-SPECIAL PROGRAMS                   531
# Librarian 1                                            530
# Truck Driver                                           527
# Pr Administrative Analyst                              512
# Assoc Engineer                                         507
# Public SafetyComm Disp                                 473
# Engineer                                               471
# POLICE OFFICER I                                       467
# HSA Sr Eligibility Worker                              467
# Asst Engr                                              461
# Stationary Eng, Sewage Plant                           457
# Senior Account Clerk                                   439
# Health Worker 3                                        438
# Automotive Mechanic                                    436
# Electronic Maintenance Tech                            430
# Manager III                                            421
# StdntDsgnTrain1, Arch/Eng/Plng                         417
# Health Worker 2                                        415
# Manager II                                             399
# Nursing Assistant                                      392
# Physician Specialist                                   392
# Senior Physician Specialist                            390
# Manager I                                              388
# Deputy Probation Officer                               377
# ATTORNEY (CIVIL/CRIMINAL)                              377
# GENERAL LABORER                                        377
# Psychiatric Social Worker                              376
# Pool Lifeguard                                         374
# PORTER                                                 370
# Administrative Analyst                                 368
# Painter                                                363
# POLICE OFFICER II                                      361
# Clerk Typist                                           352
# Principal Clerk                                        350
# Automotive Service Worker                              340
# Manager IV                                             330
# PUBLIC SERVICE TRAINEE                                 328
# Senior Personnel Analyst                               328
# PS Aide Health Services                                319
# Counselor, Juvenile Hall                               319
# Inspector 3                                            318
# Electrician                                            317
# SENIOR CLERK TYPIST                                    310
# LIBRARY PAGE                                           308
# SENIOR ELIGIBILITY WORKER                              308
# Lieutenant 3                                           303
# Secretary 2                                            301
# FIRE FIGHTER PARAMEDIC                                 301
# Medical Social Worker                                  298
# SERGEANT III (POLICE DEPARTMENT)                       295
# Library Assistant                                      294
# GARDENER                                               293
# IS Business Analyst-Principal                          289
# Deputy Court Clerk II                                  288
# Eng/Arch/Landscape Arch Sr                             285
# Accountant III                                         278
# PARKING CONTROL OFFICER                                272
# IS Engineer-Senior                                     271
# Transit Car Cleaner                                    268
# Account Clerk                                          268
# Nurse Manager                                          262
# Hospital Eligiblity Worker                             257
# IS Business Analyst-Senior                             251
# Manager V                                              251
# Senior Deputy Sheriff                                  250
# Marriage, Family & Child Cnslr                         249
# Senior Social Worker                                   244
# Management Assistant                                   241
# Library Technical Assistant 1                          237
# Personnel Analyst                                      236
# STATIONARY ENGINEER                                    226
# Accountant II                                          226
# Carpenter                                              226
# SENIOR CLERK                                           224
# ELIGIBILITY WORKER                                     220
# CLERK                                                  219
# Unit Clerk                                             218
# Automotive Machinist                                   216
# MUSEUM GUARD                                           215
# Captain, Fire Suppression                              211
# Program Specialist                                     210
# PROTECTIVE SERVICES WORKER                             208
# Junior Engineer                                        208
# NURSE PRACTITIONER                                     207
# Customer Service Agent                                 206
# ELECTRICAL TRANSIT SYSTEM MECHANIC                     204
# StdntDsgnTrain3, Arch/Eng/Plng                         204
# Pharmacy Technician                                    202
# Sr Payroll & Personnel Clerk                           199
# Deputy Court Clerk III                                 199
# TRANSIT SUPERVISOR                                     199
# Manager VI                                             198
# Junior Administrative Analyst                          198
# Plumber                                                198
# LICENSED VOCATIONAL NURSE                              194
# Swimming Instructor                                    193
# Construction Inspector                                 192
# Eligibility Worker Supervisor                          191
# SENIOR ADMINISTRATIVE ANALYST                          191
# StdntDsgn Train2/Arch/Eng/Plng                         188
# Recreation Coordinator                                 187
# AIRPORT POLICE SERVICES AIDE                           187
# Sheriff's Cadet                                        186
# Executive Secretary 1                                  184
# Legal Secretary 1                                      184
# TRUCK DRIVER                                           182
# LIBRARIAN I                                            182
# PUBLIC SERVICE AIDE-ASSOCIATE TO PROFESSIONALS         182
# Housekeeper/Food Service Clnr                          181
# Utility Plumber                                        178
# Executive Secretary 2                                  178
# Health Care Billing Clerk 2                            177
# Public Health Nurse                                    177
# Payroll Clerk                                          175
# Planner 3                                              174
# Librarian 2                                            174
# Social Worker                                          172
# Accountant IV                                          171
# LIEUTENANT, FIRE DEPARTMENT                            170
# Building Inspector                                     170
# Employment & Training Spec 3                           167
# Health Program Coordinator 3                           167
# Child Support Officer II                               167
# BdComm Mbr, Grp5,M$100/Mo                              166
# Physical Therapist                                     166
# Pharmacist                                             165
# MEDICAL EVALUATIONS ASSISTANT                          165
# Custodial Assistant Supervisor                         164
# Station Agent, Muni Railway                            164
# Admission Attendant                                    164
# Health Worker 1                                        163
# INSPECTOR III, (POLICE DEPARTMENT)                     162
# DEPUTY COURT CLERK II                                  162
# JUNIOR CLERK                                           159
# ENGINEER                                               159
# PUBLIC SAFETY COMMUNICATIONS DISPATCHER                159
# STATIONARY ENGINEER, SEWAGE PLANT                      158
# IS Engineer-Journey                                    158
# FOOD SERVICE WORKER                                    157
# Transit Fare Inspector                                 157
# IS Engineer-Principal                                  156
# IS Business Analyst                                    155
# Utility Specialist                                     154
# Bldg & Grounds Patrol Officer                          154
# SCHOOL CROSSING GUARD                                  154
# Medical Records Clerk                                  154
# Senior Management Assistant                            154
# Sheriff's Sergeant                                     153
# PUBLIC SERVICE AIDE-ASSISTANT TO PROFESSIONALS         151
# MANAGER III                                            150
# Camp Assistant                                         149
# Clinical Psychologist                                  149
# HEALTH WORKER III                                      148
# SENIOR ACCOUNT CLERK                                   148
# ASSOCIATE ENGINEER                                     148
# Sr. Community Devl Spc 1                               148
# IS Project Director                                    147
# Occupational Therapist                                 147
# Home Health Aide                                       146
# PRINCIPAL ADMINISTRATIVE ANALYST                       146
# ASSISTANT ENGINEER                                     146
# COUNSELOR, JUVENILE HALL                               144
# HSA Social Worker                                      141
# Senior Legal Process Clerk                             139
# Testing Technician                                     139
# PUBLIC SERVICE AIDE-HEALTH SERVICES                    139
# Statnry Eng Water Treat Plant                          138
# Clinical Pharmacist                                    138
# General Laborer Supervisor 1                           137
# Senior Water Services Clerk                            137
# Nursing Supervisor                                     137
# IT Operations Support Admn III                         137
# DEPUTY PROBATION OFFICER                               136
# SENIOR PHYSICIAN SPECIALIST                            136
# PHYSICIAN SPECIALIST                                   136
# CLERK TYPIST                                           135
# Commissioner No Benefits                               134
# Maintenance Machinist                                  133
# ELECTRONIC MAINTENANCE TECHNICIAN                      133
# Head Atty, Civil & Criminal                            131
# Sergeant 2                                             131
# SENIOR SOCIAL WORKER                                   129
# Operating Engineer, Universal                          129
# Airport Safety Officer                                 128
# Fare Collections Receiver                              128
# HEALTH WORKER II                                       127
# NURSING ASSISTANT                                      127
# Medical Records Technician                             126
# AUTOMOTIVE MECHANIC                                    126
# Junior Management Assistant                            125
# Legislative Assistant                                  125
# MANAGER I                                              124
# BdComm Mbr, Grp2,M=$25/Mtg                             124
# PSYCHIATRIC SOCIAL WORKER                              123
# Diagnostic Imaging Tech I                              123
# SECRETARY II                                           120
# Senior Collections Officer                             119
# SWIMMING INSTRUCTOR/POOL LIFEGUARD                     119
# Protective Services Supervisor                         118
#                                                       ...
# Communications Director                                  2
# MAINTENANCE MACHINIST ASSISTANT SUPERVISOR               2
# Court Asst., Superior Court                              2
# ELEVATOR AND CRANE TECHNICIAN                            2
# PRINCIPAL PARTS STOREKEEPER                              2
# MEDICAL EXAMINER'S INVESTIGATOR III                      2
# Senior Offset Machine Operator                           2
# Crime Lab Mgr                                            2
# ADMINISTRATIVE ANALYST II                                2
# IS TRAINER - ASSISTANT                                   2
# ASSOCIATE HUMAN RESOURCES ANALYST                        1
# TRAINING COORDINATOR                                     1
# ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN            1
# Mobile Equipment Supervisor                              1
# Court Supervisor I                                       1
# ASSISTANT DIRECTOR, LOG CABIN RANCH                      1
# Administrative Hearing Sup                               1
# ASSOCIATE MUSEUM CONSERVATOR, ASIAN ART MUSEUM           1
# TELECOMMUNICATIONS TECHNICIAN SUPERVISOR                 1
# CONSERVATORSHIP/CASE MGNT SUPV                           1
# POWER GENERATION TECHNICIAN I                            1
# LOCKSMITH SUPERVISOR I                                   1
# COURT SUPERVISOR I                                       1
# MEDIA PRODUCTION SUPERVISOR                              1
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI       1
# Police Services Aide                                     1
# SENIOR PLAN CHECKER                                      1
# SENIOR BOOK REPAIRER                                     1
# SHADE AND DRAPERY WORKER                                 1
# COURT PARALEGAL                                          1
# SECRETARY, LIBRARY COMMISSION                            1
# CITY ATTORNEY                                            1
# WAREHOUSE WORKER                                         1
# DIRECTOR, FISCAL SERVICES                                1
# WINDOW CLEANER SUPERVISOR                                1
# RENT BOARD SUPERVISOR                                    1
# FARMER                                                   1
# LIEUTENANT II (POLICE DEPARTMENT)                        1
# IS Technician Assistant                                  1
# SECRETARY, HEALTH COMMISSION                             1
# MUNICIPAL STADIUM GROUNDSKEEPER                          1
# SUPERVISING COURT ADMINISTRATIVE SECRETARY               1
# EXECUTIVE SECRETARY TO THE CONTROLLER                    1
# LIEUTENANT I, (POLICE DEPARTMENT)                        1
# COURT AD RESOLUTION COORDINATOR                          1
# SENIOR FOOD SERVICE SUPERVISOR                           1
# SENIOR TRANSIT TRAFFIC CHECKER                           1
# ASSISTANT SUPERINTENDENT RECREATION                      1
# CARPENTER SUPERVISOR II                                  1
# CHIEF OF POLICE                                          1
# PRINCIPAL RECREATION SUPERVISOR                          1
# Legislative Calendar Clerk                               1
# CHIEF ELECTRICAL INSPECTOR                               1
# ELECTRICAL ENGINEERING ASSOCIATE I                       1
# ASSISTANT LAW LIBRARIAN                                  1
# Pr DistAtty Invstgtor,SpecUnit                           1
# SENIOR OPERATIONS MANAGER                                1
# SPECIAL ASSISTANT XVI                                    1
# Special Assistant 18                                     1
# CHIEF VICTIM/WITNESS INVESTIGATOR                        1
# HUMAN RESOURCES DIRECTOR                                 1
# EMPLOYEE ASSISTANCE COUNSELOR                            1
# GLAZIER SUPERVISOR I                                     1
# ASSISTANT TO THE DIRECTOR, PUBLIC AFFAIRS       RS       1
# TRAF SIGNAL ELECTRICIAN SUP II                           1
# CHIEF MICROBIOLOGIST                                     1
# ASSESSOR                                                 1
# CASHIER III                                              1
# LEGISLATION CLERK                                        1
# Sr Sprv Prob Ofc, Juv Prob                               1
# INSTITUTIONAL POLICE LIEUTENANT                          1
# LABORATORY HELPER                                        1
# Pianist                                                  1
# MARKET RESEARCH SPECIALISTS, PORT                        1
# TRIAL DELAY REDUCTION COORDINATOR                        1
# BOARD SECRETARY - MUNICIPAL TRANSPORTATION AGENC         1
# BUILDING SERVICES TECHNICIAN                             1
# CHIEF HOUSING INSPECTOR                                  1
# MEDIA/SECURITY SYSTEMS SUPERVISOR                        1
# SECRETARY, COMMISSION ON THE ENVIRONMENT                 1
# Special Assistant 13                                     1
# ORTHOPEDIC TECHNICIAN I                                  1
# CRIME LABORATORY MANAGER                                 1
# ENVIRONMENT HEALTH TECHNICIAN II                         1
# TRAINING TECHNICIAN                                      1
# MAYORAL STAFF XI                                         1
# POWER PLANT SUPERVISOR I                                 1
# LEGISLATIVE CALENDAR CLERK                               1
# SENIOR PHARMACY HELPER                                   1
# PORT DIRECTOR                                            1
# Supervising Mediator, UFCS                               1
# SENIOR MAINTENANCE CONTROLLER                            1
# COURT EXECUTIVE OFFICER                                  1
# ASSISTANT COURT REPORTER COORDINATOR                     1
# Senior Maintenance Controller                            1
# DEPUTY DIRECTOR OF INVESTMENTS                           1
# PIANIST                                                  1
# CEMENT FINISHER SUPERVISOR II                            1
# AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS            1
# SENIOR GENERAL UTILITY MECHANIC                          1
# FEASIBILITY ANALYST, PORT                                1
# FIELD SERVICES ASSISTANT SUPERVISOR                      1
# ADMINISTRATOR, SFGH MEDICAL CENTER                       1
# EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY         1
# DISABILITY ACCESS COORDINATOR                            1
# Lieutenant (Police Department)                           1
# POWERHOUSE ELECTRICIAN SUPERVISOR II                     1
# TREASURER                                                1
# LAW LIBRARIAN                                            1
# TRAF SIGNAL ELECTRICIAN SUP I                            1
# MAYORAL STAFF V                                          1
# Asst Chf Prob Ofc, Juv Prob                              1
# Chief Forensic Toxicologist                              1
# Head Airport Electrician                                 1
# CHIEF NURSERY SPECIALIST                                 1
# DIRECTOR, HUMAN RESOURCES                                1
# MOBILE EQUIPMENT SUPERVISOR                              1
# DIRECTOR, PROBATION SERVICES                             1
# Forensic Toxicologist Supervis                           1
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS           1
# COURT INTERPRETER SUPERVISOR                             1
# PRINCIPAL MUSEUM PREPARATOR                              1
# DIRECTOR, EMPLOYEE RELATIONS DIVISION                    1
# EMERGENCY PROTECTIVE ORDERS COMMISSIONER                 1
# CHIEF PLUMBING INSPECTOR                                 1
# DIRECTOR, JUVENILE HALL                                  1
# ORNAMENTAL IRON WORKER SUPERVISOR I                      1
# ASSISTANT DIRECTOR OF CLINICAL SERVICES I                1
# IS TECHNICIAN - ASSISTANT                                1
# HEAD AIRPORT ELECTRICIAN                                 1
# PRINCIPAL INVESTIGATOR, TAX COLLECTOR                    1
# COURT CLERK                                              1
# Auto Body&Fender Wrk Asst Sprv                           1
# HEAVY EQUIPMENT OPERATIONS ASSISTANT SUPERVISOR          1
# Conversion                                               1
# TRAFFIC HEARING OFFICER                                  1
# MENTAL HEALTH HEARING OFFICER                            1
# SHERIFF                                                  1
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN                  1
# Musm Exhibit Packer & Repairer                           1
# SENIOR CLAIMS INVESTIGATOR                               1
# BAKER                                                    1
# WHARFINGER I                                             1
# COURT COMPUTER FACILITIES COORDINATOR                    1
# SENIOR MATERIALS AND SUPPLIES SUPERVISOR                 1
# SOFT FLOOR COVERER SUPERVISOR                            1
# Drug Court Coordinator                                   1
# AUDIOLOGIST                                              1
# SUPPLY ROOM ATTENDENT                                    1
# SENIOR LIGHT RAIL VEHICLE EQUIPMENT ENGINEER             1
# ANIMAL CARE ASSISTANT SUPERVISOR                         1
# LEGISLATIVE ASSISTANT, CITY ATTORNEY'S OFFICE            1
# CHIEF PROBATION OFFICER, JUVENILE COURT                  1
# ASST. CHIEF PROBATION OFFICER-JUVENILE PROBATION         1
# ACUPUNCTURIST                                            1
# METALSMITH                                               1
# ASSISTANT RECREATION SUPERVISOR                          1
# EMPLOYMENT AND TRAINING SPECIALIST VI                    1
# CONFIDENTIAL SECRETARY CITY ATTORNEY                     1
# SPECIAL ASSISTANT XIV                                    1
# SENIOR OFFSET MACHINE OPERATOR                           1
# CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE       1
# ATTORNEY FOR THE PUBLIC ADMINISTRATOR                    1
# Undersheriff (SFERS)                                     1
# ASPHALT PLANT SUPERVISOR I                               1
# SECRETARY,JUVENILE PROBATION COMMISSION                  1
# COURT ASSISTANT, SUPERIOR COURT                          1
# ANIMAL CARE SUPERVISOR                                   1
# PAINTER SUPERVISOR II                                    1
# COURT ADMINISTRATIVE SECRETARY                           1
# DIRECTOR, INFORMATION TECHNOLOGY GROUP                   1
# MATERIALS AND SUPPLIES SUPERVISOR                        1
# AREA SUPERVISOR, PARKS, SQUARES AND FACILITIES           1
# Asst Dir Clinical Svcs 2                                 1
# SUPERVISING PARTS STOREKEEPER                            1
# TRAFFIC SIGN MANAGER                                     1
# TRANSIT POWER LINE WORKER SUPERVISOR II                  1
# SUPERVISING WELFARE FRAUD INVESTIGATOR                   1
# Public Service Aide-Technical                            1
# BARBER                                                   1
# TRACK MAINTENANCE SUPERINTENDENT,MUNICIPAL RAILWAY       1
# Chief Investment Officer                                 1
# ACPO,JuvP, Juv Prob (SFERS)                              1
# PUBLIC DEFENDER                                          1
# IS TRAINER - SENIOR                                      1
# WIRE ROPE CABLE MAINTENANCE SUPERVISOR                   1
# SECRETARY, HUMAN SERVICES COMMISSION                     1
# ASSISTANT DIRECTOR, JUVENILE HALL                        1
# SENIOR DATA ENTRY OPERATOR                               1
# DEPUTY SEALER OF WEIGHTS AND MEASURES                    1
# STATISTICIAN                                             1
# SENIOR MORGUE ATTENDANT                                  1
# BRAILLIST                                                1
# CHIEF DISTRICT ATTORNEY'S INVESTIGATOR                   1
# AIRPORT MECHANICAL MAINTENANCE SUPERVISOR                1
# CHIEF TELEPHONE OPERATOR                                 1
# MAYORAL STAFF II                                         1
# HEAD PHOTOGRAPHER                                        1
# SENIOR MEDICAL TRANSCRIBER TYPIST                        1
# ASSISTANT INSPECTOR (POLICE DEPARTMENT)                  1
# $_@@#_--                                                 1
# ELECTROENCEPHALOGRAPH TECHNICIAN I                       1
# MAYOR'S PROGRAM MANAGER                                  1
# ELECTRIC MOTOR REPAIR SUPERVISOR I                       1
# TREE TOPPER SUPERVISOR II                                1
# MEDIA TRAINING SPECIALIST                                1
# FORENSIC TOXICOLOGIST                                    1
# COMMUNICATIONS DIRECTOR                                  1
# HH Mechanical Shop Sprv                                  1
# ZOO CURATOR                                              1
# SPECIAL ASSISTANT XVIII                                  1
# Sr Cnselor, Juv Hall (SFERS)                             1
# CRANE MECHANIC SUPERVISOR                                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I           1
# SECRETARY TO THE PRESIDING JUDGE                         1
# CHIEF FIRE ALARM DISPATCHER                              1
# ORTHOPEDIC TECHNICIAN II                                 1
# Cfdntal Sctry to Distric Atty                            1
# Special Assistant 8                                      1
# Light Rail Vehicle Equip Eng                             1
# VETERNIARY LABORATORY TECHNOLOGIST                       1
# MANAGER, UNIFIED FAMILY COURT SERVICES                   1
# ROOFER SUPERVISOR I                                      1
# Civil Case Settlmnt Specialist                           1
# Managing Attorney                                        1
# SHELTER OFFICE SUPERVISOR                                1
# METAL FABRICATOR                                         1
# Sheriff                                                  1
# EXECUTIVE ASSISTANT TO THE GENERAL MANAGER, RETIRE       1
# Captain, (Fire Department)                               1
# SIGNAL AND SYSTEMS ENGINEER                              1
# SHELTER OFFICE ASSISTANT SUPERVISOR                      1
# VICTIM & WITNESS TECHNICIAN                              1
# TRAFFIC SIGNAL OPERATOR                                  1
# SENIOR PSYCHIATRIC ORDERLY                               1
# CONFIDENTIAL SECRETARY TO DISTRICT ATTORNEY              1
# SPECIAL ASSISTANT XV                                     1
# COURT REPORTER COORDINATOR                               1
# Public Safety Comm Tech                                  1
# SENIOR SUPERVISING PROBATION OFFICER, JUVENILE POU       1
# TRANSIT PAINT SHOP SUPERVISOR I                          1
# SENIOR EMPLOYEE ASSISTANCE COUNSELOR                     1
# Cashier 3                                                1
# POWER HOUSE ELECTRICIAN SUPERVISOR I                     1
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)                   1
# LIBRARIAN II - ASIAN ARTS                                1
# ASSISTANT DIRECTOR OF CLINICAL SERVICES II               1
# Marina Associate Manager                                 1
# ASSISTANT INDUSTRIAL HYGIENIST                           1
# CITY PLANNING GRAPHICS SUPERVISOR                        1
# Name: JobTitle, Length: 2160, dtype: int64

# %%
df[["EmployeeName","TotalPay"]]
# Out:
#              EmployeeName   TotalPay
# 0          NATHANIEL FORD  567595.43
# 1            GARY JIMENEZ  538909.28
# 2          ALBERT PARDINI  335279.91
# 3       CHRISTOPHER CHONG  332343.61
# 4         PATRICK GARDNER  326373.19
# ...                   ...        ...
# 148649      Roy I Tillery       0.00
# 148650       Not provided       0.00
# 148651       Not provided       0.00
# 148652       Not provided       0.00
# 148653          Joe Lopez    -618.13
#
# [148654 rows x 2 columns]

# %%
col=df[["EmployeeName","TotalPay"]].values.ravel()
a=pd.unique(col)
a
# Out:
# array(['NATHANIEL FORD', 567595.43, 'GARY JIMENEZ', ..., 'Not provided',
#        'Joe Lopez', -618.13], dtype=object)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148652                                    Not provided        NaN
# 148653                      Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       NaN  567595.43         567595.43  2011
# 1         245131.88  137811.38       NaN  538909.28         538909.28  2011
# 2         106088.18   16452.60       NaN  335279.91         335279.91  2011
# 3          56120.71  198306.90       NaN  332343.61         332343.61  2011
# 4           9737.00  182234.59       NaN  326373.19         326373.19  2011
# ...             ...        ...       ...        ...               ...   ...
# 148649         0.00       0.00       0.0       0.00              0.00  2014
# 148650          NaN        NaN       NaN       0.00              0.00  2014
# 148651          NaN        NaN       NaN       0.00              0.00  2014
# 148652          NaN        NaN       NaN       0.00              0.00  2014
# 148653         0.00    -618.13       0.0    -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 0         NaN  San Francisco     NaN
# 1         NaN  San Francisco     NaN
# 2         NaN  San Francisco     NaN
# 3         NaN  San Francisco     NaN
# 4         NaN  San Francisco     NaN
# ...       ...            ...     ...
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# 148651    NaN  San Francisco     NaN
# 148652    NaN  San Francisco     NaN
# 148653    NaN  San Francisco     NaN
#
# [148654 rows x 13 columns]

# %% [markdown]
# ### Selecting Data

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
newdf = df1[(df1['BasePay'] > 99000) & (df1['BasePay'] < 110000)]
len(newdf)
# Out:
# 8727

# %%
newdf.head()
# Out:
#     Id      EmployeeName                            JobTitle    BasePay  \
# 11  12  PATRICIA JACKSON     CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 33  34        JOHN TURSI  INSPECTOR III, (POLICE DEPARTMENT)  104861.39
# 35  36        KHOA TRINH   ELECTRONIC MAINTENANCE TECHNICIAN  101953.20
# 61  62        ANNA BROWN     CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 91  92     DONNA MEIXNER     CAPTAIN III (POLICE DEPARTMENT)  102722.40
#
#     OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 11     87082.62  110804.30       NaN  297608.92         297608.92  2011
# 33     50227.61  103499.39       NaN  258588.39         258588.39  2011
# 35    139102.95   16483.94       NaN  257540.09         257540.09  2011
# 61      7437.00  128543.64       NaN  238551.88         238551.88  2011
# 91      7437.00  118456.21       NaN  228615.61         228615.61  2011
#
#     Notes         Agency  Status
# 11    NaN  San Francisco     NaN
# 33    NaN  San Francisco     NaN
# 35    NaN  San Francisco     NaN
# 61    NaN  San Francisco     NaN
# 91    NaN  San Francisco     NaN

# %%
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
def find_length(name):
    return len(name)

# %%
def times2(cols):
    x=cols[0]
    y=cols[1]
    return x*y

# %%
times2(4,4)
# Out:
# 16

# %%
df1["TotalPay_revised"]=df1[['TotalPay','BasePay']].apply(times2,axis=1)
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status  TotalPay_revised
# 0  2011    NaN  San Francisco     NaN      9.502182e+10
# 1  2011    NaN  San Francisco     NaN      8.405154e+10
# 2  2011    NaN  San Francisco     NaN      7.132716e+10
# 3  2011    NaN  San Francisco     NaN      2.589488e+10
# 4  2011    NaN  San Francisco     NaN      4.386508e+10

# %%
df1["length_of_names"]=df1['EmployeeName'].apply(find_length)
df1.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status  length_of_names
# 0  2011    NaN  San Francisco     NaN               14
# 1  2011    NaN  San Francisco     NaN               12
# 2  2011    NaN  San Francisco     NaN               14
# 3  2011    NaN  San Francisco     NaN               17
# 4  2011    NaN  San Francisco     NaN               15

# %%
df1.sort_values(by='BasePay',ascending=True) #inplace=False by default
# Out:
#             Id     EmployeeName          JobTitle  BasePay  OvertimePay  \
# 72832    72833   Irwin Sidharta      Junior Clerk  -166.01       249.02
# 72865    72866     Robert Scott      Junior Clerk  -121.63       182.70
# 72872    72873  Chung Huey Kung      Junior Clerk  -109.22       163.83
# 72874    72875        Jordan Li      Junior Clerk  -106.60       159.90
# 72878    72879  Richard Jackson      Junior Clerk  -101.88       153.08
# ...        ...              ...               ...      ...          ...
# 110530  110531    David P Kucia  Police Officer 3      NaN         0.00
# 148646  148647     Not provided      Not provided      NaN          NaN
# 148650  148651     Not provided      Not provided      NaN          NaN
# 148651  148652     Not provided      Not provided      NaN          NaN
# 148652  148653     Not provided      Not provided      NaN          NaN
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 72832        0.0      6.56     83.01             89.57  2012    NaN
# 72865        0.0      5.44     61.07             66.51  2012    NaN
# 72872        0.0      4.32     54.61             58.93  2012    NaN
# 72874        0.0      4.66     53.30             57.96  2012    NaN
# 72878        0.0      4.55     51.20             55.75  2012    NaN
# ...          ...       ...       ...               ...   ...    ...
# 110530       0.0    -33.89      0.00            -33.89  2013    NaN
# 148646       NaN       NaN      0.00              0.00  2014    NaN
# 148650       NaN       NaN      0.00              0.00  2014    NaN
# 148651       NaN       NaN      0.00              0.00  2014    NaN
# 148652       NaN       NaN      0.00              0.00  2014    NaN
#
#                Agency  Status
# 72832   San Francisco     NaN
# 72865   San Francisco     NaN
# 72872   San Francisco     NaN
# 72874   San Francisco     NaN
# 72878   San Francisco     NaN
# ...               ...     ...
# 110530  San Francisco     NaN
# 148646  San Francisco     NaN
# 148650  San Francisco     NaN
# 148651  San Francisco     NaN
# 148652  San Francisco     NaN
#
# [148654 rows x 13 columns]

# %%
df1.head()
# Out:
#             Id          EmployeeName                      JobTitle    BasePay  \
# 72925    72926        Gregory P Suhr               Chief of Police  319275.01
# 110532  110533            Amy P Hart             Asst Med Examiner  318835.49
# 72929    72930         Robert L Shaw  Dep Dir for Investments, Ret  315572.01
# 72926    72927  Joanne M Hayes-White        Chief, Fire Department  313686.01
# 72931    72932     Harlan L Kelly-Jr   Executive Contract Employee  313312.52
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 72925          0.00  20007.06  86533.21  339282.07         425815.28  2013
# 110532     10712.95  60563.54  89540.23  390111.98         479652.21  2014
# 72929          0.00      0.00  82849.66  315572.01         398421.67  2013
# 72926          0.00  23236.00  85431.39  336922.01         422353.40  2013
# 72931          0.00      0.00  82319.51  313312.52         395632.03  2013
#
#         Notes         Agency  Status  length_of_names
# 72925     NaN  San Francisco     NaN               14
# 110532    NaN  San Francisco     NaN               10
# 72929     NaN  San Francisco     NaN               13
# 72926     NaN  San Francisco     NaN               20
# 72931     NaN  San Francisco     NaN               17

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
#Select from DataFrame using criteria from multiple columns
newdf = df[(df['col1']>2) | (df['col2']==444)]

# %%
newdf
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def times2(x):
    return x*2

# %%
def to_upper(x):
    return x.upper()

# %%
def find_length(x):
    return len(x)

# %%
df['col3']=df['col3'].apply(to_upper)
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  ABC              3
# 1     2   555  DEF              3
# 2     3   666  GHI              3
# 3     4   444  XYZ              3

# %%
df['col2'].apply(times2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df["length_of_col"]=df['col3'].apply(find_length)
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  abc              3
# 1     2   555  def              3
# 2     3   666  ghi              3
# 3     4   444  xyz              3

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  ABC              3
# 1     2   555  DEF              3
# 2     3   666  GHI              3
# 3     4   444  XYZ              3

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df.head()
# Out:
#    col1  col2 col3  length_of_col
# 0     1   444  ABC              3
# 1     2   555  DEF              3
# 2     3   666  GHI              3
# 3     4   444  XYZ              3

# %%
df['col1'].sum()
# Out:
# 10

# %% [markdown]
# ** Get column and index names: **

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values(by='col2') #inplace=False by default
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df_new=df["col1"].sort_values(ascending=False)
df_new
# Out:
# 3    4
# 2    3
# 1    2
# 0    1
# Name: col1, dtype: int64

# %%
df.sort_values(by='col3',ascending=False) #inplace=False by default
# Out:
#    col1  col2 col3
# 3     4   444  xyz
# 2     3   666  ghi
# 1     2   555  def
# 0     1   444  abc

# %%
df.sort_values(by='col3',ascending=True) #inplace=False by default
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ** Filling in NaN values with something else: **

# %%
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.isnull().sum()
# Out:
# col1    1
# col2    1
# col3    0
# dtype: int64

# %%
# str_cols = ['Name','City']
str_cols = df.columns[df.dtypes==object]
df[str_cols] = df[str_cols].fillna('.')
df = df.fillna(0)
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df["col2"]=df["col2"].fillna(df["col2"].mean())
df.head()
# Out:
#    col1   col2 col3
# 0   1.0  555.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.head()
# Out:
# 0    555.0
# 1    555.0
# 2    666.0
# 3    444.0
# Name: col2, dtype: float64

# %%
df.fillna({'col1':0,'col2':0},inplace=True)

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0    0.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   0.0  444.0  xyz

# %%
# importing pandas as pd
import pandas as pd
import numpy as np
   
# creating a dataframe
df = pd.DataFrame({'A': ['John', 'Boby', 'Mina', 'Peter', 'Nicky'],
      'B': ['Masters', 'Graduate', 'Graduate', 'Masters', 'Graduate'],
      'C': [27, 23, 21, 23, 24]})
   
df.head()
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24

# %%
table = pd.pivot_table(df, index =['A', 'B'])
  
table
# Out:
#                  C
# A     B
# Boby  Graduate  23
# John  Masters   27
# Mina  Graduate  21
# Nicky Graduate  24
# Peter Masters   23

# %%
df.head()
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24

# %%
# Creates a pivot table dataframe
table = pd.pivot_table(df, values ='A', index =['B', 'C'],
						columns =['B'], aggfunc = np.sum)

table
# Out:
# B           Graduate Masters
# B        C
# Graduate 21     Mina     NaN
#          23     Boby     NaN
#          24    Nicky     NaN
# Masters  23      NaN   Peter
#          27      NaN    John

# %% [markdown]
# # Great Job!
